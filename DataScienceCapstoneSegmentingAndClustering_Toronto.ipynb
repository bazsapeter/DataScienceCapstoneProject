# %% [markdown]
# #Segment and clustering Toronto
# ###written by Peter Bazsa
#
# Our first task in Data Science Capstone Project course was to create a code that segments and classify the most common venues in Toronto, Canada.
#
# I downloaded a dataset about this from Wikipedia, with the given URL. This is followed by the cleansing of this dataset and adding the location data like longitude and latitude. After this I could use the Foursquare API to load the user feedbacks about the venues. The end of the project was the classification of this dataset by the Neighborhood.

# %% [markdown]
# ###First of all, I need to import all of the required libraries that I will use

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !pip install geopy
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !pip install folium
import folium # map rendering library

print('Libraries imported.')
# Out:
# Requirement already satisfied: geopy in f:\programs\anaconda\lib\site-packages (1.22.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in f:\programs\anaconda\lib\site-packages (from geopy) (1.50)
# Requirement already satisfied: folium in f:\programs\anaconda\lib\site-packages (0.11.0)
# Requirement already satisfied: branca>=0.3.0 in f:\programs\anaconda\lib\site-packages (from folium) (0.4.1)
# Requirement already satisfied: numpy in f:\programs\anaconda\lib\site-packages (from folium) (1.16.5)
# Requirement already satisfied: jinja2>=2.9 in f:\programs\anaconda\lib\site-packages (from folium) (2.10.3)
# Requirement already satisfied: requests in f:\programs\anaconda\lib\site-packages (from folium) (2.22.0)
# Requirement already satisfied: MarkupSafe>=0.23 in f:\programs\anaconda\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in f:\programs\anaconda\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in f:\programs\anaconda\lib\site-packages (from requests->folium) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in f:\programs\anaconda\lib\site-packages (from requests->folium) (1.24.2)
# Requirement already satisfied: certifi>=2017.4.17 in f:\programs\anaconda\lib\site-packages (from requests->folium) (2019.9.11)
# Libraries imported.

# %% [markdown]
# ###The next step is to import the dataset and clean it

# %%
#parsing the dataset from url
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

data = pd.read_html(url)
df = pd.DataFrame(data[0])
df = df[df.Borough != 'Not assigned'] #dropping rows according to "Not assigned" values in Borough feature

#Checking the result
df.head()
# Out:
#   Postal Code           Borough                                 Neighborhood
# 2         M3A        North York                                    Parkwoods
# 3         M4A        North York                             Victoria Village
# 4         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 5         M6A        North York             Lawrence Manor, Lawrence Heights
# 6         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %%
#Checking the shape
df.shape
# Out:
# (103, 3)

# %% [markdown]
# ###The next step is to add the longitude and latitude data to our dataset and clean it

# %%
#Loading the given .csv dataset into my project, then checking its shape
df_loc = pd.read_csv("Geospatial_Coordinates.csv")
df_loc.shape
# Out:
# (103, 3)

# %%
#Merging and cleaning the dataset
df_new = pd.merge(df, df_loc, on = df["Postal Code"]) #Merging the two separated dataset into one
df_new.drop(columns = ["key_0", "Postal Code_y"], inplace = True)
df_new.rename(columns={"Postal Code_x":"Postal Code"}, inplace = True)

#Checking the dataset
df_new.head()
# Out:
#   Postal Code           Borough                                 Neighborhood  \
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#     Latitude  Longitude
# 0  43.806686 -79.194353
# 1  43.784535 -79.160497
# 2  43.763573 -79.188711
# 3  43.770992 -79.216917
# 4  43.773136 -79.239476

# %% [markdown]
# ###Now I have the cleaned dataset that can be processed. Next step is to use the Foursquare API and get the most common venues in Toronto

# %% [markdown]
# First I created a map of Toronto

# %%
address = 'Toronto, CA'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.

# %%
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(df_new['Latitude'], df_new['Longitude'], df_new['Borough'], df_new['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Next, join to the Foursquare API and making some requests

# %%
CLIENT_ID = '0MFCFREMOK4AFUKGFNYWNXCOUYXBAV42GI5EBWJD0MHGQWLB' # your Foursquare ID
CLIENT_SECRET = 'PK0OAQYGL2DVPJADSJR2IP5VRIUNBFM1AX3NRDYGPCL3B5LA' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)

def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

toronto_data = df_new
LIMIT = 500
toronto_venues = getNearbyVenues(names=toronto_data['Neighborhood'],
                                   latitudes=toronto_data['Latitude'],
                                   longitudes=toronto_data['Longitude']
                                  )

print(toronto_venues.shape)
toronto_venues.head()

toronto_venues.groupby('Neighborhood').count()
print('There are {} uniques categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# Your credentails:
# CLIENT_ID: 0MFCFREMOK4AFUKGFNYWNXCOUYXBAV42GI5EBWJD0MHGQWLB
# CLIENT_SECRET:PK0OAQYGL2DVPJADSJR2IP5VRIUNBFM1AX3NRDYGPCL3B5LA
# Parkwoods
# Victoria Village
# Regent Park, Harbourfront
# Lawrence Manor, Lawrence Heights
# Queen's Park, Ontario Provincial Government
# Islington Avenue, Humber Valley Village
# Malvern, Rouge
# Don Mills
# Parkview Hill, Woodbine Gardens
# Garden District, Ryerson
# Glencairn
# West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale
# Rouge Hill, Port Union, Highland Creek
# Don Mills
# Woodbine Heights
# St. James Town
# Humewood-Cedarvale
# Eringate, Bloordale Gardens, Old Burnhamthorpe, Markland Wood
# Guildwood, Morningside, West Hill
# The Beaches
# Berczy Park
# Caledonia-Fairbanks
# Woburn
# Leaside
# Central Bay Street
# Christie
# Cedarbrae
# Hillcrest Village
# Bathurst Manor, Wilson Heights, Downsview North
# Thorncliffe Park
# Richmond, Adelaide, King
# Dufferin, Dovercourt Village
# Scarborough Village
# Fairview, Henry Farm, Oriole
# Northwood Park, York University
# East Toronto, Broadview North (Old East York)
# Harbourfront East, Union Station, Toronto Islands
# Little Portugal, Trinity
# Kennedy Park, Ionview, East Birchmount Park
# Bayview Village
# Downsview
# The Danforth West, Riverdale
# Toronto Dominion Centre, Design Exchange
# Brockton, Parkdale Village, Exhibition Place
# Golden Mile, Clairlea, Oakridge
# York Mills, Silver Hills
# Downsview
# India Bazaar, The Beaches West
# Commerce Court, Victoria Hotel
# North Park, Maple Leaf Park, Upwood Park
# Humber Summit
# Cliffside, Cliffcrest, Scarborough Village West
# Willowdale, Newtonbrook
# Downsview
# Studio District
# Bedford Park, Lawrence Manor East
# Del Ray, Mount Dennis, Keelsdale and Silverthorn
# Humberlea, Emery
# Birch Cliff, Cliffside West
# Willowdale, Willowdale East
# Downsview
# Lawrence Park
# Roselawn
# Runnymede, The Junction North
# Weston
# Dorset Park, Wexford Heights, Scarborough Town Centre
# York Mills West
# Davisville North
# Forest Hill North & West, Forest Hill Road Park
# High Park, The Junction South
# Westmount
# Wexford, Maryvale
# Willowdale, Willowdale West
# North Toronto West, Lawrence Park
# The Annex, North Midtown, Yorkville
# Parkdale, Roncesvalles
# Canada Post Gateway Processing Centre
# Kingsview Village, St. Phillips, Martin Grove Gardens, Richview Gardens
# Agincourt
# Davisville
# University of Toronto, Harbord
# Runnymede, Swansea
# Clarks Corners, Tam O'Shanter, Sullivan
# Moore Park, Summerhill East
# Kensington Market, Chinatown, Grange Park
# Milliken, Agincourt North, Steeles East, L'Amoreaux East
# Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park
# CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport
# New Toronto, Mimico South, Humber Bay Shores
# South Steeles, Silverstone, Humbergate, Jamestown, Mount Olive, Beaumond Heights, Thistletown, Albion Gardens
# Steeles West, L'Amoreaux West
# Rosedale
# Stn A PO Boxes
# Alderwood, Long Branch
# Northwest, West Humber - Clairville
# Upper Rouge
# St. James Town, Cabbagetown
# First Canadian Place, Underground city
# The Kingsway, Montgomery Road, Old Mill North
# Church and Wellesley
# Business reply mail Processing Centre, South Central Letter Processing Plant Toronto
# Old Mill South, King's Mill Park, Sunnylea, Humber Bay, Mimico NE, The Queensway East, Royal York South East, Kingsway Park South East
# Mimico NW, The Queensway West, South of Bloor, Kingsway Park South West, Royal York South West
# (2132, 7)
# There are 280 uniques categories.

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()

num_top_venues = 5

for hood in toronto_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = toronto_grouped[toronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Agincourt----
#             venue  freq
# 0            Café  0.13
# 1          Bakery  0.09
# 2  Breakfast Spot  0.09
# 3     Coffee Shop  0.09
# 4       Pet Store  0.04
#
#
# ----Bathurst Manor, Wilson Heights, Downsview North----
#               venue  freq
# 0              Bank  0.10
# 1       Coffee Shop  0.10
# 2        Restaurant  0.05
# 3  Sushi Restaurant  0.05
# 4       Supermarket  0.05
#
#
# ----Bayview Village----
#                   venue  freq
# 0        Sandwich Place  0.09
# 1     Indian Restaurant  0.09
# 2           Yoga Studio  0.05
# 3   Housing Development  0.05
# 4  Fast Food Restaurant  0.05
#
#
# ----Bedford Park, Lawrence Manor East----
#                  venue  freq
# 0                 Café  0.06
# 1          Coffee Shop  0.06
# 2         Cocktail Bar  0.05
# 3  American Restaurant  0.04
# 4            Gastropub  0.04
#
#
# ----Berczy Park----
#                              venue  freq
# 0                        Cafeteria   1.0
# 1                    Metro Station   0.0
# 2  Molecular Gastronomy Restaurant   0.0
# 3       Modern European Restaurant   0.0
# 4                Mobile Phone Shop   0.0
#
#
# ----Birch Cliff, Cliffside West----
#            venue  freq
# 0    Coffee Shop  0.09
# 1           Café  0.05
# 2     Restaurant  0.05
# 3          Hotel  0.03
# 4  Deli / Bodega  0.03
#
#
# ----Brockton, Parkdale Village, Exhibition Place----
#          venue  freq
# 0         Café  0.10
# 1  Coffee Shop  0.07
# 2      Brewery  0.05
# 3       Bakery  0.05
# 4    Gastropub  0.05
#
#
# ----Business reply mail Processing Centre, South Central Letter Processing Plant Toronto----
#                venue  freq
# 0        Pizza Place  0.25
# 1           Bus Line  0.25
# 2  Mobile Phone Shop  0.25
# 3     Sandwich Place  0.25
# 4     Massage Studio  0.00
#
#
# ----CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport----
#                   venue  freq
# 0           Yoga Studio  0.06
# 1         Auto Workshop  0.06
# 2  Gym / Fitness Center  0.06
# 3         Garden Center  0.06
# 4                Garden  0.06
#
#
# ----Canada Post Gateway Processing Centre----
#       venue  freq
# 0    Bakery  0.13
# 1  Pharmacy  0.13
# 2      Bank  0.07
# 3       Bar  0.07
# 4   Brewery  0.07
#
#
# ----Cedarbrae----
#                   venue  freq
# 0  Caribbean Restaurant  0.17
# 1   Japanese Restaurant  0.17
# 2    Athletics & Sports  0.17
# 3  Gym / Fitness Center  0.17
# 4                  Café  0.17
#
#
# ----Central Bay Street----
#            venue  freq
# 0       Pharmacy  0.17
# 1  Grocery Store  0.17
# 2        Butcher  0.17
# 3           Bank  0.17
# 4    Coffee Shop  0.17
#
#
# ----Christie----
#                         venue  freq
# 0             Fireworks Store  0.33
# 1                        Park  0.33
# 2           Food & Drink Shop  0.33
# 3                 Men's Store  0.00
# 4  Modern European Restaurant  0.00
#
#
# ----Church and Wellesley----
#                 venue  freq
# 0         Pizza Place  0.25
# 1         Coffee Shop  0.12
# 2      Sandwich Place  0.12
# 3  Chinese Restaurant  0.12
# 4        Intersection  0.12
#
#
# ----Clarks Corners, Tam O'Shanter, Sullivan----
#                 venue  freq
# 0                Café  0.09
# 1     Thai Restaurant  0.09
# 2  Mexican Restaurant  0.09
# 3       Grocery Store  0.04
# 4                 Bar  0.04
#
#
# ----Cliffside, Cliffcrest, Scarborough Village West----
#          venue  freq
# 0  Coffee Shop  0.06
# 1   Restaurant  0.06
# 2  Pizza Place  0.06
# 3         Café  0.06
# 4       Bakery  0.04
#
#
# ----Commerce Court, Victoria Hotel----
#                         venue  freq
# 0                        Park   0.5
# 1                         Gym   0.5
# 2                 Yoga Studio   0.0
# 3                 Men's Store   0.0
# 4  Modern European Restaurant   0.0
#
#
# ----Davisville----
#                         venue  freq
# 0                       Trail   0.2
# 1  Construction & Landscaping   0.2
# 2                      Bakery   0.2
# 3                        Park   0.2
# 4            Basketball Court   0.2
#
#
# ----Davisville North----
#                            venue  freq
# 0                           Café  0.08
# 1                    Coffee Shop  0.07
# 2  Vegetarian / Vegan Restaurant  0.05
# 3          Vietnamese Restaurant  0.05
# 4             Mexican Restaurant  0.05
#
#
# ----Del Ray, Mount Dennis, Keelsdale and Silverthorn----
#                 venue  freq
# 0         Coffee Shop  0.07
# 1        Cocktail Bar  0.05
# 2          Restaurant  0.04
# 3              Bakery  0.04
# 4  Seafood Restaurant  0.04
#
#
# ----Don Mills----
#              venue  freq
# 0      Pizza Place  0.09
# 1         Bus Line  0.09
# 2           Bakery  0.09
# 3         Pharmacy  0.05
# 4  Thai Restaurant  0.05
#
#
# ----Dorset Park, Wexford Heights, Scarborough Town Centre----
#             venue  freq
# 0  Sandwich Place  0.14
# 1            Café  0.14
# 2     Coffee Shop  0.09
# 3    Burger Joint  0.05
# 4       BBQ Joint  0.05
#
#
# ----Downsview----
#          venue  freq
# 0  Coffee Shop  0.11
# 1        Hotel  0.05
# 2         Café  0.05
# 3   Restaurant  0.04
# 4       Bakery  0.03
#
#
# ----Dufferin, Dovercourt Village----
#            venue  freq
# 0           Park  0.25
# 1  Grocery Store  0.25
# 2           Bank  0.25
# 3  Shopping Mall  0.25
# 4    Yoga Studio  0.00
#
#
# ----East Toronto, Broadview North (Old East York)----
#                 venue  freq
# 0         Pizza Place  0.18
# 1                Café  0.09
# 2        Intersection  0.09
# 3           Gastropub  0.09
# 4  Athletics & Sports  0.09
#
#
# ----Eringate, Bloordale Gardens, Old Burnhamthorpe, Markland Wood----
#                       venue  freq
# 0               Golf Course   0.2
# 1      Fast Food Restaurant   0.2
# 2                   Dog Run   0.2
# 3                      Pool   0.2
# 4  Mediterranean Restaurant   0.2
#
#
# ----Fairview, Henry Farm, Oriole----
#                   venue  freq
# 0        Discount Store   0.2
# 1          Liquor Store   0.2
# 2  Gym / Fitness Center   0.2
# 3         Grocery Store   0.2
# 4    Athletics & Sports   0.2
#
#
# ----First Canadian Place, Underground city----
#                         venue  freq
# 0              Baseball Field   0.5
# 1                Food Service   0.5
# 2                 Yoga Studio   0.0
# 3               Metro Station   0.0
# 4  Modern European Restaurant   0.0
#
#
# ----Forest Hill North & West, Forest Hill Road Park----
#               venue  freq
# 0   Airport Service  0.17
# 1    Airport Lounge  0.11
# 2  Airport Terminal  0.11
# 3             Plane  0.06
# 4   Harbor / Marina  0.06
#
#
# ----Garden District, Ryerson----
#                    venue  freq
# 0                   Café  0.25
# 1        College Stadium  0.25
# 2  General Entertainment  0.25
# 3           Skating Rink  0.25
# 4            Yoga Studio  0.00
#
#
# ----Glencairn----
#                    venue  freq
# 0      Indian Restaurant   0.4
# 1  Vietnamese Restaurant   0.2
# 2     Chinese Restaurant   0.2
# 3              Pet Store   0.2
# 4   Other Great Outdoors   0.0
#
#
# ----Golden Mile, Clairlea, Oakridge----
#            venue  freq
# 0           Park  0.33
# 1    Swim School  0.33
# 2       Bus Line  0.33
# 3    Yoga Studio  0.00
# 4  Metro Station  0.00
#
#
# ----Guildwood, Morningside, West Hill----
#                   venue  freq
# 0        Clothing Store  0.13
# 1           Coffee Shop  0.08
# 2  Fast Food Restaurant  0.06
# 3   Japanese Restaurant  0.05
# 4            Restaurant  0.03
#
#
# ----Harbourfront East, Union Station, Toronto Islands----
#                 venue  freq
# 0            Pharmacy  0.12
# 1         Video Store  0.12
# 2                 Spa  0.12
# 3  Athletics & Sports  0.12
# 4        Skating Rink  0.12
#
#
# ----High Park, The Junction South----
#                  venue  freq
# 0          Coffee Shop  0.10
# 1                 Café  0.04
# 2   Seafood Restaurant  0.03
# 3   Italian Restaurant  0.03
# 4  Japanese Restaurant  0.03
#
#
# ----Hillcrest Village----
#                  venue  freq
# 0  Sporting Goods Shop  0.09
# 1           Beer Store  0.09
# 2                  Gym  0.09
# 3           Restaurant  0.09
# 4          Coffee Shop  0.09
#
#
# ----Humber Summit----
#                         venue  freq
# 0                        Park  0.50
# 1                       Trail  0.25
# 2                  Playground  0.25
# 3                 Yoga Studio  0.00
# 4  Modern European Restaurant  0.00
#
#
# ----Humberlea, Emery----
#                  venue  freq
# 0          Coffee Shop  0.17
# 1                 Café  0.08
# 2   Italian Restaurant  0.06
# 3  Japanese Restaurant  0.05
# 4       Sandwich Place  0.05
#
#
# ----India Bazaar, The Beaches West----
#             venue  freq
# 0    Dessert Shop  0.10
# 1  Sandwich Place  0.10
# 2     Pizza Place  0.06
# 3     Coffee Shop  0.06
# 4             Gym  0.06
#
#
# ----Islington Avenue, Humber Valley Village----
#                         venue  freq
# 0                  Playground   0.5
# 1  Construction & Landscaping   0.5
# 2                 Yoga Studio   0.0
# 3                 Men's Store   0.0
# 4  Modern European Restaurant   0.0
#
#
# ----Kennedy Park, Ionview, East Birchmount Park----
#                  venue  freq
# 0          Coffee Shop  0.12
# 1  Sporting Goods Shop  0.06
# 2         Burger Joint  0.06
# 3                 Bank  0.06
# 4        Shopping Mall  0.06
#
#
# ----Kensington Market, Chinatown, Grange Park----
#                 venue  freq
# 0         Coffee Shop  0.11
# 1                Café  0.08
# 2    Sushi Restaurant  0.08
# 3  Italian Restaurant  0.05
# 4                 Pub  0.05
#
#
# ----Kingsview Village, St. Phillips, Martin Grove Gardens, Richview Gardens----
#                            venue  freq
# 0                            Bar  0.11
# 1               Asian Restaurant  0.07
# 2                     Restaurant  0.04
# 3  Vegetarian / Vegan Restaurant  0.04
# 4                    Coffee Shop  0.04
#
#
# ----Lawrence Manor, Lawrence Heights----
#                              venue  freq
# 0                      Coffee Shop  0.67
# 1                Korean Restaurant  0.33
# 2                      Yoga Studio  0.00
# 3                    Metro Station  0.00
# 4  Molecular Gastronomy Restaurant  0.00
#
#
# ----Lawrence Park----
#                  venue  freq
# 0          Coffee Shop  0.11
# 1           Restaurant  0.07
# 2                 Café  0.07
# 3                Hotel  0.05
# 4  American Restaurant  0.04
#
#
# ----Leaside----
#                         venue  freq
# 0                        Park   0.5
# 1           Convenience Store   0.5
# 2                 Yoga Studio   0.0
# 3                 Men's Store   0.0
# 4  Modern European Restaurant   0.0
#
#
# ----Little Portugal, Trinity----
#                         venue  freq
# 0                         Pub  0.25
# 1           Health Food Store  0.25
# 2                       Trail  0.25
# 3                 Yoga Studio  0.00
# 4  Modern European Restaurant  0.00
#
#
# ----Malvern, Rouge----
#                venue  freq
# 0     Discount Store   0.2
# 1  Convenience Store   0.2
# 2        Bus Station   0.2
# 3   Department Store   0.2
# 4        Coffee Shop   0.2
#
#
# ----Milliken, Agincourt North, Steeles East, L'Amoreaux East----
#               venue  freq
# 0       Coffee Shop  0.22
# 1  Sushi Restaurant  0.06
# 2       Yoga Studio  0.03
# 3          Creperie  0.03
# 4          Beer Bar  0.03
#
#
# ----Mimico NW, The Queensway West, South of Bloor, Kingsway Park South West, Royal York South West----
#                         venue  freq
# 0         Rental Car Location   0.5
# 1                   Drugstore   0.5
# 2                 Yoga Studio   0.0
# 3         Monument / Landmark   0.0
# 4  Modern European Restaurant   0.0
#
#
# ----Moore Park, Summerhill East----
#                          venue  freq
# 0               Breakfast Spot  0.14
# 1                    Gift Shop  0.14
# 2                  Coffee Shop  0.07
# 3  Eastern European Restaurant  0.07
# 4                          Bar  0.07
#
#
# ----New Toronto, Mimico South, Humber Bay Shores----
#                  venue  freq
# 0             Pharmacy  0.08
# 1         Liquor Store  0.08
# 2                 Café  0.08
# 3           Restaurant  0.08
# 4  Fried Chicken Joint  0.08
#
#
# ----North Park, Maple Leaf Park, Upwood Park----
#                  venue  freq
# 0   Light Rail Station  0.12
# 1                  Pub  0.12
# 2          Coffee Shop  0.12
# 3           Bagel Shop  0.06
# 4  Fried Chicken Joint  0.06
#
#
# ----North Toronto West, Lawrence Park----
#           venue  freq
# 0         Trail  0.25
# 1         Field  0.25
# 2  Tennis Court  0.25
# 3  Hockey Arena  0.25
# 4   Yoga Studio  0.00
#
#
# ----Northwood Park, York University----
#                    venue  freq
# 0  Portuguese Restaurant  0.25
# 1          Grocery Store  0.25
# 2           Hockey Arena  0.25
# 3            Coffee Shop  0.25
# 4     Mexican Restaurant  0.00
#
#
# ----Old Mill South, King's Mill Park, Sunnylea, Humber Bay, Mimico NE, The Queensway East, Royal York South East, Kingsway Park South East----
#                   venue  freq
# 0           Pizza Place  0.22
# 1         Grocery Store  0.22
# 2        Sandwich Place  0.11
# 3  Fast Food Restaurant  0.11
# 4            Beer Store  0.11
#
#
# ----Parkdale, Roncesvalles----
#                 venue  freq
# 0       Grocery Store  0.25
# 1                Café  0.19
# 2                Park  0.12
# 3         Coffee Shop  0.06
# 4  Italian Restaurant  0.06
#
#
# ----Parkview Hill, Woodbine Gardens----
#                  venue  freq
# 0                Motel   0.5
# 1  American Restaurant   0.5
# 2     Malay Restaurant   0.0
# 3               Market   0.0
# 4    Martial Arts Dojo   0.0
#
#
# ----Parkwoods----
#                         venue  freq
# 0        Fast Food Restaurant   1.0
# 1                 Yoga Studio   0.0
# 2                 Men's Store   0.0
# 3  Modern European Restaurant   0.0
# 4           Mobile Phone Shop   0.0
#
#
# ----Queen's Park, Ontario Provincial Government----
#                  venue  freq
# 0     Hakka Restaurant  0.12
# 1   Athletics & Sports  0.12
# 2  Fried Chicken Joint  0.12
# 3                 Bank  0.12
# 4               Bakery  0.12
#
#
# ----Regent Park, Harbourfront----
#                  venue  freq
# 0    Electronics Store  0.14
# 1  Rental Car Location  0.14
# 2       Breakfast Spot  0.14
# 3       Medical Center  0.14
# 4                 Bank  0.14
#
#
# ----Richmond, Adelaide, King----
#               venue  freq
# 0           Airport  0.25
# 1              Park  0.25
# 2  Business Service  0.25
# 3       Snack Place  0.25
# 4       Yoga Studio  0.00
#
#
# ----Rosedale----
#                         venue  freq
# 0              Baseball Field   1.0
# 1                 Yoga Studio   0.0
# 2               Metro Station   0.0
# 3  Modern European Restaurant   0.0
# 4           Mobile Phone Shop   0.0
#
#
# ----Roselawn----
#                      venue  freq
# 0               Restaurant  0.08
# 1       Italian Restaurant  0.08
# 2           Sandwich Place  0.08
# 3              Coffee Shop  0.08
# 4  Comfort Food Restaurant  0.04
#
#
# ----Rouge Hill, Port Union, Highland Creek----
#                        venue  freq
# 0             Clothing Store   0.2
# 1                     Lounge   0.2
# 2             Breakfast Spot   0.2
# 3  Latin American Restaurant   0.2
# 4               Skating Rink   0.2
#
#
# ----Runnymede, Swansea----
#                              venue  freq
# 0                      Pizza Place  0.33
# 1                Convenience Store  0.33
# 2             Caribbean Restaurant  0.33
# 3               Mexican Restaurant  0.00
# 4  Molecular Gastronomy Restaurant  0.00
#
#
# ----Runnymede, The Junction North----
#                  venue  freq
# 0               Garden  0.33
# 1       Ice Cream Shop  0.33
# 2         Home Service  0.33
# 3   Mexican Restaurant  0.00
# 4  Monument / Landmark  0.00
#
#
# ----Scarborough Village----
#                venue  freq
# 0         Food Truck  0.25
# 1   Business Service  0.25
# 2     Baseball Field  0.25
# 3  Korean Restaurant  0.25
# 4      Metro Station  0.00
#
#
# ----South Steeles, Silverstone, Humbergate, Jamestown, Mount Olive, Beaumond Heights, Thistletown, Albion Gardens----
#                 venue  freq
# 0         Pizza Place  0.22
# 1            Pharmacy  0.11
# 2                 Pub  0.11
# 3  Athletics & Sports  0.11
# 4        Dance Studio  0.11
#
#
# ----St. James Town----
#                     venue  freq
# 0      Chinese Restaurant  0.12
# 1                Pharmacy  0.06
# 2  Thrift / Vintage Store  0.06
# 3            Burger Joint  0.06
# 4    Fast Food Restaurant  0.06
#
#
# ----St. James Town, Cabbagetown----
#                         venue  freq
# 0                 Pizza Place   0.5
# 1      Furniture / Home Store   0.5
# 2               Metro Station   0.0
# 3  Modern European Restaurant   0.0
# 4           Mobile Phone Shop   0.0
#
#
# ----Steeles West, L'Amoreaux West----
#                         venue  freq
# 0                        Park   0.5
# 1                       River   0.5
# 2                 Yoga Studio   0.0
# 3               Metro Station   0.0
# 4  Modern European Restaurant   0.0
#
#
# ----Stn A PO Boxes----
#            venue  freq
# 0   Burger Joint  0.06
# 1            Gym  0.06
# 2         Bakery  0.06
# 3  Tanning Salon  0.06
# 4     Kids Store  0.06
#
#
# ----Studio District----
#                 venue  freq
# 0      Clothing Store  0.09
# 1         Coffee Shop  0.08
# 2      Cosmetics Shop  0.03
# 3  Italian Restaurant  0.03
# 4     Bubble Tea Shop  0.03
#
#
# ----Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park----
#                  venue  freq
# 0                Hotel  0.15
# 1          Coffee Shop  0.15
# 2  American Restaurant  0.08
# 3         Intersection  0.08
# 4       Sandwich Place  0.08
#
#
# ----The Annex, North Midtown, Yorkville----
#                         venue  freq
# 0                        Park  0.50
# 1               Women's Store  0.25
# 2                        Pool  0.25
# 3                 Men's Store  0.00
# 4  Modern European Restaurant  0.00
#
#
# ----The Beaches----
#                  venue  freq
# 0                 Café  0.25
# 1  Japanese Restaurant  0.25
# 2                 Bank  0.25
# 3   Chinese Restaurant  0.25
# 4   Miscellaneous Shop  0.00
#
#
# ----The Danforth West, Riverdale----
#                     venue  freq
# 0        Greek Restaurant  0.19
# 1             Coffee Shop  0.07
# 2      Italian Restaurant  0.07
# 3              Restaurant  0.05
# 4  Furniture / Home Store  0.05
#
#
# ----The Kingsway, Montgomery Road, Old Mill North----
#                         venue  freq
# 0                        Park  0.67
# 1           Convenience Store  0.33
# 2                 Yoga Studio  0.00
# 3                 Men's Store  0.00
# 4  Modern European Restaurant  0.00
#
#
# ----Thorncliffe Park----
#                     venue  freq
# 0  Furniture / Home Store  0.17
# 1          Massage Studio  0.17
# 2    Caribbean Restaurant  0.17
# 3                     Bar  0.17
# 4           Metro Station  0.17
#
#
# ----Toronto Dominion Centre, Design Exchange----
#                   venue  freq
# 0  Fast Food Restaurant  0.10
# 1        Sandwich Place  0.10
# 2           Pizza Place  0.05
# 3          Liquor Store  0.05
# 4            Steakhouse  0.05
#
#
# ----University of Toronto, Harbord----
#             venue  freq
# 0  Discount Store   0.2
# 1     Coffee Shop   0.2
# 2      Restaurant   0.2
# 3             Bar   0.2
# 4  Sandwich Place   0.2
#
#
# ----Upper Rouge----
#             venue  freq
# 0     Pizza Place  0.12
# 1    Liquor Store  0.12
# 2  Shopping Plaza  0.12
# 3     Coffee Shop  0.12
# 4      Beer Store  0.12
#
#
# ----Victoria Village----
#                              venue  freq
# 0       Construction & Landscaping   0.5
# 1                              Bar   0.5
# 2                      Yoga Studio   0.0
# 3               Mexican Restaurant   0.0
# 4  Molecular Gastronomy Restaurant   0.0
#
#
# ----West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale----
#                        venue  freq
# 0  Middle Eastern Restaurant  0.33
# 1                Auto Garage  0.17
# 2             Breakfast Spot  0.17
# 3                     Bakery  0.17
# 4             Sandwich Place  0.17
#
#
# ----Westmount----
#          venue  freq
# 0  Coffee Shop  0.10
# 1         Café  0.08
# 2   Restaurant  0.04
# 3          Gym  0.04
# 4        Hotel  0.04
#
#
# ----Weston----
#                              venue  freq
# 0                    Jewelry Store  0.25
# 1               Mexican Restaurant  0.25
# 2                 Sushi Restaurant  0.25
# 3                            Trail  0.25
# 4  Molecular Gastronomy Restaurant  0.00
#
#
# ----Wexford, Maryvale----
#                     venue  freq
# 0  Furniture / Home Store  0.18
# 1          Clothing Store  0.18
# 2                Boutique  0.09
# 3             Event Space  0.09
# 4      Miscellaneous Shop  0.09
#
#
# ----Willowdale, Newtonbrook----
#                  venue  freq
# 0          Coffee Shop  0.08
# 1     Sushi Restaurant  0.06
# 2  Japanese Restaurant  0.05
# 3              Gay Bar  0.04
# 4           Restaurant  0.04
#
#
# ----Willowdale, Willowdale East----
#          venue  freq
# 0  Coffee Shop  0.13
# 1     Aquarium  0.05
# 2         Café  0.04
# 3        Hotel  0.04
# 4   Restaurant  0.03
#
#
# ----Willowdale, Willowdale West----
#                  venue  freq
# 0          Pizza Place  0.33
# 1     Sushi Restaurant  0.17
# 2     Asian Restaurant  0.17
# 3  Japanese Restaurant  0.17
# 4                  Pub  0.17
#
#
# ----Woburn----
#               venue  freq
# 0  Ramen Restaurant  0.09
# 1    Sandwich Place  0.06
# 2       Coffee Shop  0.06
# 3       Pizza Place  0.06
# 4              Café  0.06
#
#
# ----Woodbine Heights----
#                         venue  freq
# 0                  Playground   0.5
# 1                        Park   0.5
# 2                 Yoga Studio   0.0
# 3                 Men's Store   0.0
# 4  Modern European Restaurant   0.0
#
#
# ----York Mills West----
#                  venue  freq
# 0                 Café  0.14
# 1   Italian Restaurant  0.06
# 2  Japanese Restaurant  0.06
# 3                  Bar  0.06
# 4            Bookstore  0.06
#
#
# ----York Mills, Silver Hills----
#                   venue  freq
# 0                  Park  0.11
# 1  Gym / Fitness Center  0.11
# 2      Department Store  0.11
# 3                 Hotel  0.11
# 4                   Gym  0.11

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                       Neighborhood 1st Most Common Venue  \
# 0                                        Agincourt                  Café
# 1  Bathurst Manor, Wilson Heights, Downsview North           Coffee Shop
# 2                                  Bayview Village        Sandwich Place
# 3                Bedford Park, Lawrence Manor East           Coffee Shop
# 4                                      Berczy Park             Cafeteria
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0           Coffee Shop        Breakfast Spot                Bakery
# 1                  Bank        Sandwich Place      Sushi Restaurant
# 2     Indian Restaurant           Yoga Studio           Coffee Shop
# 3                  Café          Cocktail Bar   American Restaurant
# 4         Women's Store             Drugstore                 Diner
#
#   5th Most Common Venue   6th Most Common Venue 7th Most Common Venue  \
# 0         Grocery Store  Furniture / Home Store     Convenience Store
# 1        Ice Cream Shop           Deli / Bodega            Restaurant
# 2          Burger Joint                Bus Line            Restaurant
# 3             Gastropub          Cosmetics Shop      Department Store
# 4        Discount Store     Distribution Center               Dog Run
#
#        8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0      Performing Arts Venue             Pet Store           Climbing Gym
# 1  Middle Eastern Restaurant     Mobile Phone Shop    Fried Chicken Joint
# 2                Pizza Place              Pharmacy         Discount Store
# 3                        Gym    Italian Restaurant         Clothing Store
# 4           Doner Restaurant            Donut Shop    Dumpling Restaurant

# %% [markdown]
# I got the dataset that is ready for clustering

# %% [markdown]
# ###The next step is to define the clusters then do the algorythm.
#
# I tried to create clustering similar to NY lab.

# %%
# set number of clusters
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]

# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_merged = toronto_data

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

# casting Cluster Labels values from float to int
toronto_merged["Cluster Labels"] = toronto_merged["Cluster Labels"].fillna(0.0).astype(int)

toronto_merged.head() # check the last columns!
# Out:
#   Postal Code           Borough                                 Neighborhood  \
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#     Latitude  Longitude  Cluster Labels       1st Most Common Venue  \
# 0  43.806686 -79.194353               3        Fast Food Restaurant
# 1  43.784535 -79.160497               2  Construction & Landscaping
# 2  43.763573 -79.188711               2              Medical Center
# 3  43.770992 -79.216917               2                 Coffee Shop
# 4  43.773136 -79.239476               2            Hakka Restaurant
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0             Drugstore                 Diner        Discount Store
# 1                   Bar         Women's Store             Drugstore
# 2    Mexican Restaurant        Breakfast Spot     Electronics Store
# 3     Korean Restaurant         Women's Store   Dumpling Restaurant
# 4           Gas Station                Bakery    Athletics & Sports
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0   Distribution Center               Dog Run      Doner Restaurant
# 1        Discount Store   Distribution Center               Dog Run
# 2   Rental Car Location          Intersection                  Bank
# 3        Discount Store   Distribution Center               Dog Run
# 4                  Bank  Caribbean Restaurant       Thai Restaurant
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0            Donut Shop   Dumpling Restaurant                  Field
# 1      Doner Restaurant            Donut Shop    Dumpling Restaurant
# 2      Doner Restaurant   Distribution Center                Dog Run
# 3      Doner Restaurant            Donut Shop              Drugstore
# 4   Fried Chicken Joint   Dumpling Restaurant              Drugstore

# %% [markdown]
# ###And the last thing to do is to visualize it on the map

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Now you can see every neighborhood in the map which cluster they are belong to.
#
# ###Lets examine them.

# %%
#First cluster listed
toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[1] + [2] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough                            Neighborhood  Cluster Labels  \
# 16              York                      Humewood-Cedarvale               0
# 21              York                     Caledonia-Fairbanks               0
# 91  Downtown Toronto                                Rosedale               0
# 93         Etobicoke                  Alderwood, Long Branch               0
# 94         Etobicoke     Northwest, West Humber - Clairville               0
# 97  Downtown Toronto  First Canadian Place, Underground city               0
#
#    1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 16                   NaN                   NaN                   NaN
# 21                   NaN                   NaN                   NaN
# 91        Baseball Field         Women's Store        Discount Store
# 93                   NaN                   NaN                   NaN
# 94                   NaN                   NaN                   NaN
# 97          Food Service        Baseball Field         Women's Store
#
#    4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 16                   NaN                   NaN                   NaN
# 21                   NaN                   NaN                   NaN
# 91   Distribution Center               Dog Run      Doner Restaurant
# 93                   NaN                   NaN                   NaN
# 94                   NaN                   NaN                   NaN
# 97                 Field        Discount Store   Distribution Center
#
#    7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 16                   NaN                   NaN                   NaN
# 21                   NaN                   NaN                   NaN
# 91            Donut Shop             Drugstore   Dumpling Restaurant
# 93                   NaN                   NaN                   NaN
# 94                   NaN                   NaN                   NaN
# 97               Dog Run      Doner Restaurant            Donut Shop
#
#    10th Most Common Venue
# 16                    NaN
# 21                    NaN
# 91     Dim Sum Restaurant
# 93                    NaN
# 94                    NaN
# 97              Drugstore

# %%
#Second cluster listed
toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[[1] + [2] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough                                   Neighborhood  \
# 14         East York                               Woodbine Heights
# 23         East York                                        Leaside
# 25  Downtown Toronto                                       Christie
# 44       Scarborough                Golden Mile, Clairlea, Oakridge
# 48  Downtown Toronto                 Commerce Court, Victoria Hotel
# 50        North York                                  Humber Summit
# 74   Central Toronto            The Annex, North Midtown, Yorkville
# 90       Scarborough                  Steeles West, L'Amoreaux West
# 98         Etobicoke  The Kingsway, Montgomery Road, Old Mill North
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 14               1                  Park            Playground
# 23               1                  Park     Convenience Store
# 25               1     Food & Drink Shop                  Park
# 44               1                  Park              Bus Line
# 48               1                   Gym                  Park
# 50               1                  Park                 Trail
# 74               1                  Park                  Pool
# 90               1                  Park                 River
# 98               1                  Park     Convenience Store
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 14            Donut Shop    Dim Sum Restaurant                 Diner
# 23         Women's Store   Dumpling Restaurant        Discount Store
# 25       Fireworks Store         Women's Store        Discount Store
# 44           Swim School  Fast Food Restaurant                 Diner
# 48         Women's Store             Drugstore                 Diner
# 50            Playground    Dim Sum Restaurant                 Diner
# 74         Women's Store      Greek Restaurant         Deli / Bodega
# 90      Department Store    Dim Sum Restaurant                 Diner
# 98         Women's Store   Dumpling Restaurant        Discount Store
#
#    6th Most Common Venue 7th Most Common Venue        8th Most Common Venue  \
# 14        Discount Store   Distribution Center                      Dog Run
# 23   Distribution Center               Dog Run             Doner Restaurant
# 25   Distribution Center               Dog Run             Doner Restaurant
# 44        Discount Store   Distribution Center                      Dog Run
# 48        Discount Store   Distribution Center                      Dog Run
# 50        Discount Store   Distribution Center                      Dog Run
# 74  Ethiopian Restaurant     Electronics Store  Eastern European Restaurant
# 90        Discount Store   Distribution Center                      Dog Run
# 98   Distribution Center               Dog Run             Doner Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 14      Doner Restaurant              Drugstore
# 23            Donut Shop              Drugstore
# 25            Donut Shop              Drugstore
# 44      Doner Restaurant             Donut Shop
# 48      Doner Restaurant             Donut Shop
# 50      Doner Restaurant             Donut Shop
# 74   Dumpling Restaurant              Drugstore
# 90      Doner Restaurant             Donut Shop
# 98            Donut Shop              Drugstore

# %%
#Third cluster listed
toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[[1] + [2] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#               Borough                                       Neighborhood  \
# 1          North York                                   Victoria Village
# 2    Downtown Toronto                          Regent Park, Harbourfront
# 3          North York                   Lawrence Manor, Lawrence Heights
# 4    Downtown Toronto        Queen's Park, Ontario Provincial Government
# 5           Etobicoke            Islington Avenue, Humber Valley Village
# 6         Scarborough                                     Malvern, Rouge
# 7          North York                                          Don Mills
# 8           East York                    Parkview Hill, Woodbine Gardens
# 9    Downtown Toronto                           Garden District, Ryerson
# 10         North York                                          Glencairn
# 11          Etobicoke  West Deane Park, Princess Gardens, Martin Grov...
# 12        Scarborough             Rouge Hill, Port Union, Highland Creek
# 13         North York                                          Don Mills
# 15   Downtown Toronto                                     St. James Town
# 17          Etobicoke  Eringate, Bloordale Gardens, Old Burnhamthorpe...
# 18        Scarborough                  Guildwood, Morningside, West Hill
# 19       East Toronto                                        The Beaches
# 20   Downtown Toronto                                        Berczy Park
# 22        Scarborough                                             Woburn
# 26        Scarborough                                          Cedarbrae
# 27         North York                                  Hillcrest Village
# 28         North York    Bathurst Manor, Wilson Heights, Downsview North
# 29          East York                                   Thorncliffe Park
# 30   Downtown Toronto                           Richmond, Adelaide, King
# 31       West Toronto                       Dufferin, Dovercourt Village
# 32        Scarborough                                Scarborough Village
# 33         North York                       Fairview, Henry Farm, Oriole
# 34         North York                    Northwood Park, York University
# 36   Downtown Toronto  Harbourfront East, Union Station, Toronto Islands
# 37       West Toronto                           Little Portugal, Trinity
# 38        Scarborough        Kennedy Park, Ionview, East Birchmount Park
# 39         North York                                    Bayview Village
# 40         North York                                          Downsview
# 41       East Toronto                       The Danforth West, Riverdale
# 42   Downtown Toronto           Toronto Dominion Centre, Design Exchange
# 43       West Toronto       Brockton, Parkdale Village, Exhibition Place
# 45         North York                           York Mills, Silver Hills
# 46         North York                                          Downsview
# 47       East Toronto                     India Bazaar, The Beaches West
# 49         North York           North Park, Maple Leaf Park, Upwood Park
# 51        Scarborough    Cliffside, Cliffcrest, Scarborough Village West
# 52         North York                            Willowdale, Newtonbrook
# 53         North York                                          Downsview
# 54       East Toronto                                    Studio District
# 55         North York                  Bedford Park, Lawrence Manor East
# 56               York   Del Ray, Mount Dennis, Keelsdale and Silverthorn
# 57         North York                                   Humberlea, Emery
# 58        Scarborough                        Birch Cliff, Cliffside West
# 59         North York                        Willowdale, Willowdale East
# 60         North York                                          Downsview
# 61    Central Toronto                                      Lawrence Park
# 62    Central Toronto                                           Roselawn
# 63               York                      Runnymede, The Junction North
# 64               York                                             Weston
# 65        Scarborough  Dorset Park, Wexford Heights, Scarborough Town...
# 66         North York                                    York Mills West
# 67    Central Toronto                                   Davisville North
# 68    Central Toronto    Forest Hill North & West, Forest Hill Road Park
# 69       West Toronto                      High Park, The Junction South
# 70          Etobicoke                                          Westmount
# 71        Scarborough                                  Wexford, Maryvale
# 73    Central Toronto                  North Toronto West, Lawrence Park
# 75       West Toronto                             Parkdale, Roncesvalles
# 76        Mississauga              Canada Post Gateway Processing Centre
# 77          Etobicoke  Kingsview Village, St. Phillips, Martin Grove ...
# 78        Scarborough                                          Agincourt
# 79    Central Toronto                                         Davisville
# 80   Downtown Toronto                     University of Toronto, Harbord
# 82        Scarborough            Clarks Corners, Tam O'Shanter, Sullivan
# 83    Central Toronto                        Moore Park, Summerhill East
# 84   Downtown Toronto          Kensington Market, Chinatown, Grange Park
# 85        Scarborough  Milliken, Agincourt North, Steeles East, L'Amo...
# 86    Central Toronto  Summerhill West, Rathnelly, South Hill, Forest...
# 87   Downtown Toronto  CN Tower, King and Spadina, Railway Lands, Har...
# 88          Etobicoke       New Toronto, Mimico South, Humber Bay Shores
# 92   Downtown Toronto                                     Stn A PO Boxes
# 95        Scarborough                                        Upper Rouge
# 102         Etobicoke  Mimico NW, The Queensway West, South of Bloor,...
#
#      Cluster Labels       1st Most Common Venue       2nd Most Common Venue  \
# 1                 2  Construction & Landscaping                         Bar
# 2                 2              Medical Center          Mexican Restaurant
# 3                 2                 Coffee Shop           Korean Restaurant
# 4                 2            Hakka Restaurant                 Gas Station
# 5                 2                  Playground  Construction & Landscaping
# 6                 2              Discount Store                 Bus Station
# 7                 2                 Pizza Place                    Bus Line
# 8                 2                       Motel         American Restaurant
# 9                 2                        Café       General Entertainment
# 10                2           Indian Restaurant                   Pet Store
# 11                2   Middle Eastern Restaurant                 Auto Garage
# 12                2                      Lounge   Latin American Restaurant
# 13                2                 Pizza Place                    Bus Line
# 15                2          Chinese Restaurant                         Gym
# 17                2        Fast Food Restaurant    Mediterranean Restaurant
# 18                2              Clothing Store                 Coffee Shop
# 19                2                        Café                        Bank
# 20                2                   Cafeteria               Women's Store
# 22                2            Ramen Restaurant                 Pizza Place
# 26                2        Gym / Fitness Center         Japanese Restaurant
# 27                2                         Gym                  Restaurant
# 28                2                 Coffee Shop                        Bank
# 29                2               Metro Station      Furniture / Home Store
# 30                2                        Park            Business Service
# 31                2                        Park                        Bank
# 32                2            Business Service                  Food Truck
# 33                2        Gym / Fitness Center              Discount Store
# 34                2               Grocery Store                 Coffee Shop
# 36                2                        Park                Skating Rink
# 37                2                       Trail           Health Food Store
# 38                2                 Coffee Shop         Sporting Goods Shop
# 39                2              Sandwich Place           Indian Restaurant
# 40                2                 Coffee Shop                        Café
# 41                2            Greek Restaurant          Italian Restaurant
# 42                2              Sandwich Place        Fast Food Restaurant
# 43                2                        Café                 Coffee Shop
# 45                2        Gym / Fitness Center                       Hotel
# 46                2                 Coffee Shop                        Café
# 47                2              Sandwich Place                Dessert Shop
# 49                2                 Coffee Shop                         Pub
# 51                2                 Coffee Shop                 Pizza Place
# 52                2                 Coffee Shop            Sushi Restaurant
# 53                2                 Coffee Shop                        Café
# 54                2              Clothing Store                 Coffee Shop
# 55                2                 Coffee Shop                        Café
# 56                2                 Coffee Shop                Cocktail Bar
# 57                2                 Coffee Shop                        Café
# 58                2                 Coffee Shop                  Restaurant
# 59                2                 Coffee Shop                    Aquarium
# 60                2                 Coffee Shop                        Café
# 61                2                 Coffee Shop                  Restaurant
# 62                2                  Restaurant              Sandwich Place
# 63                2              Ice Cream Shop                Home Service
# 64                2                       Trail          Mexican Restaurant
# 65                2              Sandwich Place                        Café
# 66                2                        Café                      Bakery
# 67                2                        Café                 Coffee Shop
# 68                2             Airport Service            Airport Terminal
# 69                2                 Coffee Shop                        Café
# 70                2                 Coffee Shop                        Café
# 71                2      Furniture / Home Store              Clothing Store
# 73                2                       Trail                       Field
# 75                2               Grocery Store                        Café
# 76                2                      Bakery                    Pharmacy
# 77                2                         Bar            Asian Restaurant
# 78                2                        Café                 Coffee Shop
# 79                2            Basketball Court                        Park
# 80                2                  Restaurant              Sandwich Place
# 82                2             Thai Restaurant                        Café
# 83                2              Breakfast Spot                   Gift Shop
# 84                2                 Coffee Shop                        Café
# 85                2                 Coffee Shop            Sushi Restaurant
# 86                2                       Hotel                 Coffee Shop
# 87                2                 Yoga Studio               Auto Workshop
# 88                2                         Gym         American Restaurant
# 92                2               Grocery Store      Thrift / Vintage Store
# 95                2                        Café                Liquor Store
# 102               2                   Drugstore         Rental Car Location
#
#           3rd Most Common Venue          4th Most Common Venue  \
# 1                 Women's Store                      Drugstore
# 2                Breakfast Spot              Electronics Store
# 3                 Women's Store            Dumpling Restaurant
# 4                        Bakery             Athletics & Sports
# 5                 Women's Store            Dumpling Restaurant
# 6              Department Store                    Coffee Shop
# 7                        Bakery                           Park
# 8                 Women's Store             Dim Sum Restaurant
# 9                  Skating Rink                College Stadium
# 10        Vietnamese Restaurant             Chinese Restaurant
# 11               Breakfast Spot                         Bakery
# 12               Breakfast Spot                   Skating Rink
# 13                       Bakery                           Park
# 15                     Pharmacy                 Sandwich Place
# 17                  Golf Course                        Dog Run
# 18         Fast Food Restaurant            Japanese Restaurant
# 19           Chinese Restaurant            Japanese Restaurant
# 20                    Drugstore                          Diner
# 22                         Café                 Sandwich Place
# 26           Athletics & Sports           Caribbean Restaurant
# 27             Asian Restaurant                     Beer Store
# 28               Sandwich Place               Sushi Restaurant
# 29         Caribbean Restaurant                    Coffee Shop
# 30                  Snack Place                        Airport
# 31                Shopping Mall                  Grocery Store
# 32            Korean Restaurant                 Baseball Field
# 33           Athletics & Sports                   Liquor Store
# 34                 Hockey Arena          Portuguese Restaurant
# 36                     Pharmacy                    Video Store
# 37                          Pub                  Women's Store
# 38                Shopping Mall                   Burger Joint
# 39                  Yoga Studio                    Coffee Shop
# 40                        Hotel                     Restaurant
# 41                  Coffee Shop                 Ice Cream Shop
# 42                 Liquor Store                 Ice Cream Shop
# 43                       Bakery                      Gastropub
# 45                          Gym                    Pizza Place
# 46                        Hotel                     Restaurant
# 47                          Gym             Italian Restaurant
# 49           Light Rail Station               Sushi Restaurant
# 51                         Café                     Restaurant
# 52          Japanese Restaurant                        Gay Bar
# 53                        Hotel                     Restaurant
# 54    Middle Eastern Restaurant                           Café
# 55                 Cocktail Bar            American Restaurant
# 56                  Cheese Shop                     Restaurant
# 57           Italian Restaurant            Japanese Restaurant
# 58                         Café                 Clothing Store
# 59                        Hotel                           Café
# 60                        Hotel                     Restaurant
# 61                         Café                          Hotel
# 62           Italian Restaurant                    Coffee Shop
# 63                       Garden             Dim Sum Restaurant
# 64             Sushi Restaurant                  Jewelry Store
# 65                  Coffee Shop                           Park
# 66           Italian Restaurant            Japanese Restaurant
# 67           Mexican Restaurant          Vietnamese Restaurant
# 68               Airport Lounge                  Boat or Ferry
# 69           Seafood Restaurant             Italian Restaurant
# 70                        Hotel                     Restaurant
# 71            Accessories Store                       Boutique
# 73                 Tennis Court                   Hockey Arena
# 75                         Park                     Baby Store
# 76    Middle Eastern Restaurant                      Pet Store
# 77                  Coffee Shop  Vegetarian / Vegan Restaurant
# 78               Breakfast Spot                         Bakery
# 79   Construction & Landscaping                         Bakery
# 80                  Coffee Shop                 Discount Store
# 82           Mexican Restaurant      Cajun / Creole Restaurant
# 83                 Dessert Shop                  Movie Theater
# 84             Sushi Restaurant                    Pizza Place
# 85                  Yoga Studio                            Bar
# 86                Burrito Place            American Restaurant
# 87                Garden Center                         Garden
# 88                   Restaurant            Fried Chicken Joint
# 92            Convenience Store                 Discount Store
# 95                    Pet Store                       Pharmacy
# 102                Dessert Shop                          Diner
#
#              5th Most Common Venue       6th Most Common Venue  \
# 1                   Discount Store         Distribution Center
# 2              Rental Car Location                Intersection
# 3                   Discount Store         Distribution Center
# 4                             Bank        Caribbean Restaurant
# 5                   Discount Store         Distribution Center
# 6                Convenience Store                   Drugstore
# 7              Fried Chicken Joint                    Pharmacy
# 8                   Discount Store         Distribution Center
# 9                     Concert Hall  Construction & Landscaping
# 10                      Donut Shop                       Diner
# 11                  Sandwich Place                  Donut Shop
# 12                  Clothing Store                   Drugstore
# 13             Fried Chicken Joint                    Pharmacy
# 15                    Burger Joint                 Coffee Shop
# 17                            Pool                       Diner
# 18                   Women's Store           Electronics Store
# 19                           Diner         Distribution Center
# 20                  Discount Store         Distribution Center
# 22                Sushi Restaurant                 Coffee Shop
# 26                  Baseball Field                        Café
# 27                     Coffee Shop         Sporting Goods Shop
# 28                  Ice Cream Shop               Deli / Bodega
# 29                  Massage Studio                         Bar
# 30                       Drugstore              Discount Store
# 31                     Event Space        Ethiopian Restaurant
# 32                   Women's Store                   Drugstore
# 33                   Grocery Store              Farmers Market
# 34                   Women's Store                  Donut Shop
# 36                             Spa                  Beer Store
# 37                           Diner              Discount Store
# 38                            Bank      Furniture / Home Store
# 39                    Burger Joint                    Bus Line
# 40                          Bakery                        Park
# 41                       Bookstore      Furniture / Home Store
# 42                Sushi Restaurant           Fish & Chips Shop
# 43                         Brewery         American Restaurant
# 45                Department Store              Sandwich Place
# 46                          Bakery                        Park
# 47                     Coffee Shop                        Café
# 49           Vietnamese Restaurant                  Bagel Shop
# 51                             Pub                      Bakery
# 52                      Restaurant    Mediterranean Restaurant
# 53                          Bakery                        Park
# 54                  Cosmetics Shop             Bubble Tea Shop
# 55                       Gastropub              Cosmetics Shop
# 56                            Café          Seafood Restaurant
# 57                  Sandwich Place                Burger Joint
# 58                             Gym               Deli / Bodega
# 59                         Brewery          Italian Restaurant
# 60                          Bakery                        Park
# 61                             Gym         American Restaurant
# 62                     Pizza Place                        Café
# 63                           Diner              Discount Store
# 64                   Women's Store              Discount Store
# 65                     Pizza Place                  Donut Shop
# 66                             Bar                   Bookstore
# 67   Vegetarian / Vegan Restaurant                      Bakery
# 68             Rental Car Location                       Plane
# 69                      Restaurant                    Beer Bar
# 70             Japanese Restaurant                         Gym
# 71                     Event Space       Vietnamese Restaurant
# 73              Dim Sum Restaurant              Discount Store
# 75                      Restaurant                 Candy Store
# 76                            Bank                 Supermarket
# 77                      Restaurant                        Café
# 78                   Grocery Store      Furniture / Home Store
# 79                           Trail         Dumpling Restaurant
# 80                             Bar               Women's Store
# 82                    Antique Shop                 Flea Market
# 83                         Dog Run                   Bookstore
# 84              Italian Restaurant                         Pub
# 85                        Beer Bar               Smoothie Shop
# 86       Middle Eastern Restaurant                Intersection
# 87            Fast Food Restaurant          Light Rail Station
# 88                    Liquor Store          Mexican Restaurant
# 92                   Burrito Place                Burger Joint
# 95                     Pizza Place                  Beer Store
# 102                 Discount Store         Distribution Center
#
#       7th Most Common Venue        8th Most Common Venue  \
# 1                   Dog Run             Doner Restaurant
# 2                      Bank             Doner Restaurant
# 3                   Dog Run             Doner Restaurant
# 4           Thai Restaurant          Fried Chicken Joint
# 5                   Dog Run             Doner Restaurant
# 6       Distribution Center                      Dog Run
# 7        Chinese Restaurant                Metro Station
# 8                   Dog Run             Doner Restaurant
# 9        Falafel Restaurant                  Event Space
# 10           Discount Store          Distribution Center
# 11      Distribution Center                      Dog Run
# 12           Discount Store          Distribution Center
# 13       Chinese Restaurant                Metro Station
# 15              Pizza Place       Thrift / Vintage Store
# 17           Discount Store          Distribution Center
# 18                     Bank                   Restaurant
# 19                  Dog Run             Doner Restaurant
# 20                  Dog Run             Doner Restaurant
# 22           Ice Cream Shop                   Steakhouse
# 26      Distribution Center                      Dog Run
# 27              Art Gallery               Discount Store
# 28               Restaurant    Middle Eastern Restaurant
# 29            Women's Store          Distribution Center
# 30      Distribution Center                      Dog Run
# 31        Electronics Store  Eastern European Restaurant
# 32                  Dog Run             Doner Restaurant
# 33       Falafel Restaurant                  Event Space
# 34       Dim Sum Restaurant                        Diner
# 36       Athletics & Sports                  Curling Ice
# 37      Distribution Center                      Dog Run
# 38            Smoothie Shop               Breakfast Spot
# 39               Restaurant                  Pizza Place
# 40                      Pub               Clothing Store
# 41               Restaurant                  Yoga Studio
# 42                  Brewery            Food & Drink Shop
# 43              Yoga Studio      Comfort Food Restaurant
# 45           Breakfast Spot            Food & Drink Shop
# 46                      Pub               Clothing Store
# 47         Sushi Restaurant                  Pizza Place
# 49             Liquor Store                         Bank
# 51                     Park           Chinese Restaurant
# 52              Men's Store                         Café
# 53                      Pub               Clothing Store
# 54       Italian Restaurant          Japanese Restaurant
# 55         Department Store                          Gym
# 56                   Bakery                     Beer Bar
# 57         Department Store              Bubble Tea Shop
# 58                    Hotel              Thai Restaurant
# 59           Scenic Lookout                   Restaurant
# 60                      Pub               Clothing Store
# 61       Seafood Restaurant                Deli / Bodega
# 62                      Pub             Sushi Restaurant
# 63      Distribution Center                      Dog Run
# 64      Distribution Center                      Dog Run
# 65             Burger Joint            Indian Restaurant
# 66               Restaurant                          Pub
# 67            Grocery Store                         Park
# 68              Coffee Shop             Sculpture Garden
# 69             Cocktail Bar          Japanese Restaurant
# 70       Seafood Restaurant                  Salad Place
# 71       Miscellaneous Shop                  Coffee Shop
# 73      Distribution Center                      Dog Run
# 75       Italian Restaurant                    Nightclub
# 76                      Bar                  Music Venue
# 77              Men's Store            Korean Restaurant
# 78        Convenience Store        Performing Arts Venue
# 79      Distribution Center                      Dog Run
# 80         Doner Restaurant                        Diner
# 82   Furniture / Home Store                    Speakeasy
# 83               Restaurant                          Bar
# 84            Grocery Store                          Bar
# 85           Sandwich Place                Burrito Place
# 86           Sandwich Place                  Gas Station
# 87           Farmers Market                   Comic Shop
# 88       Seafood Restaurant                       Bakery
# 92           Sandwich Place         Fast Food Restaurant
# 95              Coffee Shop               Shopping Plaza
# 102                 Dog Run             Doner Restaurant
#
#          9th Most Common Venue 10th Most Common Venue
# 1                   Donut Shop    Dumpling Restaurant
# 2          Distribution Center                Dog Run
# 3                   Donut Shop              Drugstore
# 4          Dumpling Restaurant              Drugstore
# 5                   Donut Shop              Drugstore
# 6             Doner Restaurant             Donut Shop
# 7          Rental Car Location            Bus Station
# 8                   Donut Shop              Drugstore
# 9         Ethiopian Restaurant      Electronics Store
# 10                     Dog Run       Doner Restaurant
# 11            Doner Restaurant              Drugstore
# 12                     Dog Run       Doner Restaurant
# 13         Rental Car Location            Bus Station
# 15           Electronics Store          Grocery Store
# 17            Doner Restaurant             Donut Shop
# 18                      Bakery      Mobile Phone Shop
# 19                  Donut Shop              Drugstore
# 20                  Donut Shop    Dumpling Restaurant
# 22                       Hotel  Indonesian Restaurant
# 26            Doner Restaurant             Donut Shop
# 27          Dim Sum Restaurant     Italian Restaurant
# 28           Mobile Phone Shop    Fried Chicken Joint
# 29                     Dog Run       Doner Restaurant
# 30            Doner Restaurant             Donut Shop
# 31         Dumpling Restaurant              Drugstore
# 32                  Donut Shop    Dumpling Restaurant
# 33        Ethiopian Restaurant      Electronics Store
# 34              Discount Store    Distribution Center
# 36               Women's Store             Donut Shop
# 37            Doner Restaurant             Donut Shop
# 38            Sushi Restaurant            Supermarket
# 39                    Pharmacy         Discount Store
# 40               Deli / Bodega                    Spa
# 41        Caribbean Restaurant      Indian Restaurant
# 42                Intersection                    Pub
# 43                   Bookstore     Seafood Restaurant
# 45                        Park         General Travel
# 46               Deli / Bodega                    Spa
# 47                Gourmet Shop        Thai Restaurant
# 49                  Restaurant            Pizza Place
# 51          Italian Restaurant                Butcher
# 52                         Pub            Yoga Studio
# 53               Deli / Bodega                    Spa
# 54                   Bookstore                  Hotel
# 55          Italian Restaurant         Clothing Store
# 56                        Park                  Diner
# 57                 Salad Place         Ice Cream Shop
# 58            Sushi Restaurant             Steakhouse
# 59         Sporting Goods Shop    Fried Chicken Joint
# 60               Deli / Bodega                    Spa
# 61          Italian Restaurant    Japanese Restaurant
# 62                Liquor Store                Butcher
# 63            Doner Restaurant             Donut Shop
# 64            Doner Restaurant             Donut Shop
# 65   Middle Eastern Restaurant              BBQ Joint
# 66                        Bank               Beer Bar
# 67                 Pizza Place           Dessert Shop
# 68                    Boutique                    Bar
# 69              Breakfast Spot                    Pub
# 70                  Steakhouse          Deli / Bodega
# 71                   Gift Shop             Donut Shop
# 73            Doner Restaurant             Donut Shop
# 75                 Coffee Shop                  Diner
# 76                        Café          Grocery Store
# 77         Japanese Restaurant                Brewery
# 78                   Pet Store           Climbing Gym
# 79            Doner Restaurant             Donut Shop
# 80         Distribution Center                Dog Run
# 82         Arts & Crafts Store                 Bakery
# 83          Italian Restaurant       Cuban Restaurant
# 84                         Spa          Smoothie Shop
# 85                        Café     College Auditorium
# 86    Mediterranean Restaurant    Fried Chicken Joint
# 87                        Park            Pizza Place
# 88                        Café            Coffee Shop
# 92                 Social Club                 Bakery
# 95            Doner Restaurant                  Diner
# 102                 Donut Shop          Women's Store

# %%
#Fourth cluster listed
toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, toronto_merged.columns[[1] + [2] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#       Borough Neighborhood  Cluster Labels 1st Most Common Venue  \
# 0  North York    Parkwoods               3  Fast Food Restaurant
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0             Drugstore                 Diner        Discount Store
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0   Distribution Center               Dog Run      Doner Restaurant
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0            Donut Shop   Dumpling Restaurant                  Field

# %%
#Fifth cluster listed
toronto_merged.loc[toronto_merged['Cluster Labels'] == 4, toronto_merged.columns[[1] + [2] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#               Borough                                       Neighborhood  \
# 24   Downtown Toronto                                 Central Bay Street
# 35          East York      East Toronto, Broadview North (Old East York)
# 72         North York                        Willowdale, Willowdale West
# 81       West Toronto                                 Runnymede, Swansea
# 89          Etobicoke  South Steeles, Silverstone, Humbergate, Jamest...
# 96   Downtown Toronto                        St. James Town, Cabbagetown
# 99   Downtown Toronto                               Church and Wellesley
# 100      East Toronto  Business reply mail Processing Centre, South C...
# 101         Etobicoke  Old Mill South, King's Mill Park, Sunnylea, Hu...
#
#      Cluster Labels 1st Most Common Venue   2nd Most Common Venue  \
# 24                4               Butcher           Grocery Store
# 35                4           Pizza Place    Gym / Fitness Center
# 72                4           Pizza Place     Japanese Restaurant
# 81                4           Pizza Place    Caribbean Restaurant
# 89                4           Pizza Place            Dance Studio
# 96                4           Pizza Place  Furniture / Home Store
# 99                4           Pizza Place          Sandwich Place
# 100               4        Sandwich Place             Pizza Place
# 101               4         Grocery Store             Pizza Place
#
#     3rd Most Common Venue      4th Most Common Venue 5th Most Common Venue  \
# 24               Pharmacy                Pizza Place                  Bank
# 35              Gastropub               Intersection                  Bank
# 72       Asian Restaurant           Sushi Restaurant                   Pub
# 81      Convenience Store              Women's Store            Donut Shop
# 89                    Gym                   Pharmacy           Coffee Shop
# 96          Women's Store                 Donut Shop    Dim Sum Restaurant
# 99           Intersection  Middle Eastern Restaurant           Coffee Shop
# 100              Bus Line          Mobile Phone Shop         Women's Store
# 101  Fast Food Restaurant                   Pharmacy            Beer Store
#
#     6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 24            Coffee Shop            Donut Shop                 Diner
# 35                   Café    Athletics & Sports  Fast Food Restaurant
# 72       Doner Restaurant                 Diner        Discount Store
# 81                  Diner        Discount Store   Distribution Center
# 89         Sandwich Place    Athletics & Sports                   Pub
# 96                  Diner        Discount Store   Distribution Center
# 99         Discount Store    Chinese Restaurant         Women's Store
# 100      Doner Restaurant                 Diner        Discount Store
# 101        Sandwich Place   Fried Chicken Joint               Dog Run
#
#     9th Most Common Venue 10th Most Common Venue
# 24         Discount Store    Distribution Center
# 35              Pet Store               Pharmacy
# 72    Distribution Center                Dog Run
# 81                Dog Run       Doner Restaurant
# 89          Women's Store    Distribution Center
# 96                Dog Run       Doner Restaurant
# 99                Dog Run    Distribution Center
# 100   Distribution Center                Dog Run
# 101    Dim Sum Restaurant                  Diner

# %% [markdown]
# This is the end of the project! I hope you enjoyed.
