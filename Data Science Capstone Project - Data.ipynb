# %% [markdown]
# # Data Science Capstone Project
#
# ## Segmenting the Crossfit Boxes in Budapest

# %% [markdown]
# ### Data Analysis

# %% [markdown]
# First is to import every library that I will need for data manipulation and building the model.

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!pip install geopy==2.2.0
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!pip install folium
import folium # map rendering library

#!pip install pyproj
import pyproj

#pyplot
import matplotlib.pyplot as plt

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# The following functions are needed for converting the lateral - longitudinal values into coordinates and vica-versa.

# %%
def xy_to_lonlat(x, y):
    proj_latlon = pyproj.Proj(proj='latlong',datum='WGS84')
    proj_xy = pyproj.Proj(proj="utm", zone=33, datum='WGS84')
    lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
    return lonlat[0], lonlat[1]

def lonlat_to_xy(lon, lat):
    proj_latlon = pyproj.Proj(proj='latlong',datum='WGS84')
    proj_xy = pyproj.Proj(proj="utm", zone=33, datum='WGS84')
    xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
    return xy[0], xy[1]

# %% [markdown]
# The next step is to load our main dataset, which contains the neighborhood names for Budapest, Hungary. The following page is used for that purpose: https://en.wikipedia.org/wiki/List_of_districts_in_Budapest
# Also, for the different dataset manipulation operations, the pandas package of python will be the proper tool.

# %%
#parsing the dataset from url
url = 'https://en.wikipedia.org/wiki/List_of_districts_in_Budapest'

data = pd.read_html(url)
df = pd.DataFrame(data = data[0])
column_names = ["DistrictNumber","DistrictName","Neighborhoods","Sights"]
df.columns = column_names
df.drop(labels = 0, axis = 0, inplace = True)
df.drop(columns="Sights", inplace = True)
df
# Out:
#    DistrictNumber                                       DistrictName  \
# 1              I.                        Várkerület(Castle District)
# 2             II.                                               none
# 3            III.                                  Óbuda-Békásmegyer
# 4             IV.                                   Újpest(New Pest)
# 5              V.       Belváros-Lipótváros(Inner City-Leopold Town)
# 6             VI.                           Terézváros(Theresa Town)
# 7            VII.                      Erzsébetváros(Elizabeth Town)
# 8           VIII.                           Józsefváros(Joseph Town)
# 9             IX.                          Ferencváros(Francis Town)
# 10             X.                                    Kőbánya(Quarry)
# 11            XI.                                   Újbuda(New Buda)
# 12           XII.                               Hegyvidék(Highlands)
# 13          XIII.                                               none
# 14           XIV.                                              Zugló
# 15            XV.                                               none
# 16           XVI.                                               none
# 17          XVII.                                         Rákosmente
# 18         XVIII.  Pestszentlőrinc-Pestszentimre(Pest Saint Lawre...
# 19   XIX. kerület                               Kispest(Little Pest)
# 20            XX.                       Pesterzsébet(Pest Elizabeth)
# 21           XXI.                                             Csepel
# 22          XXII.                                     Budafok-Tétény
# 23         XXIII.                                           Soroksár
# 24   non-district                     Margit-sziget(Margaret Island)
#
#                                         Neighborhoods
# 1   Buda Castle, Tabán, Gellérthegy, Krisztinaváro...
# 2   Adyliget, Budakeszierdő, Budaliget, Csatárka, ...
# 3   Óbuda, Aquincum, Aranyhegy, Békásmegyer, Csill...
# 4   Újpest, Megyer, Káposztásmegyer, Székesdűlő, I...
# 5                              Inner City, Lipótváros
# 6                                          Terézváros
# 7                                       Erzsébetváros
# 8          Józsefváros, Kerepesdűlő, Tisztviselőtelep
# 9   Ferencváros, Gubacsidűlő, József Attila-lakótelep
# 10  Felsőrákos, Gyárdűlő, Keresztúridűlő, Kőbánya-...
# 11  Albertfalva, Dobogó, Gazdagrét, Gellérthegy, H...
# 12  Budakeszierdő, Csillebérc, Farkasrét, Farkasvö...
# 13  Újlipótváros, Angyalföld, Vizafogó, Népsziget,...
# 14  Alsórákos, Herminamező, Istvánmező, Kiszugló, ...
# 15                  Rákospalota, Pestújhely, Újpalota
# 16  Mátyásföld, Sashalom, Cinkota, Rákosszentmihál...
# 17  Rákoskeresztúr, Rákoscsaba, Rákoscsaba-Újtelep...
# 18                     Pestszentlőrinc, Pestszentimre
# 19                              Kispest, Wekerletelep
# 20  Gubacsipuszta, Kossuthfalva, Pacsirtatelep, Pe...
# 21                                             Csepel
# 22                    Budatétény, Nagytétény, Budafok
# 23                                           Soroksár
# 24                                      Margit-sziget

# %% [markdown]
# This looks good, but I need the proper format for finding the Geo coordinates for each neighborhood, so I need some additional adjustments.

# %%
s = pd.DataFrame(df.Neighborhoods.str.split(",").tolist(), index=df.DistrictNumber).stack()
added_df = pd.DataFrame(columns=["DistrictNumber", "Neighborhood"])
added_df.Neighborhood = s.values
added_df.DistrictNumber = s.index.get_level_values("DistrictNumber")
added_df
# Out:
#     DistrictNumber               Neighborhood
# 0               I.                Buda Castle
# 1               I.                      Tabán
# 2               I.                Gellérthegy
# 3               I.             Krisztinaváros
# 4               I.         southern Víziváros
# 5              II.                   Adyliget
# 6              II.              Budakeszierdő
# 7              II.                  Budaliget
# 8              II.                   Csatárka
# 9              II.              Erzsébetliget
# 10             II.              Erzsébettelek
# 11             II.                   Felhévíz
# 12             II.                     Gercse
# 13             II.                 Hársakalja
# 14             II.                   Hárshegy
# 15             II.                 Hűvösvölgy
# 16             II.                      Kővár
# 17             II.                   Kurucles
# 18             II.                  Lipótmező
# 19             II.                Máriaremete
# 20             II.                       Nyék
# 21             II.                   Országút
# 22             II.                   Pálvölgy
# 23             II.                    Pasarét
# 24             II.         Pesthidegkút-Ófalu
# 25             II.              Petneházy-rét
# 26             II.            Remetekertváros
# 27             II.                     Rézmál
# 28             II.                  Rózsadomb
# 29             II.                 Szemlőhegy
# 30             II.                  Széphalom
# 31             II.                  Szépilona
# 32             II.                  Szépvölgy
# 33             II.                  Törökvész
# 34             II.                      Újlak
# 35             II.                   Vérhalom
# 36             II.         northern Víziváros
# 37             II.                   Zöldmál.
# 38            III.                      Óbuda
# 39            III.                   Aquincum
# 40            III.                  Aranyhegy
# 41            III.                Békásmegyer
# 42            III.                Csillaghegy
# 43            III.                  Csúcshegy
# 44            III.                Filatorigát
# 45            III.           Hármashatár-hegy
# 46            III.                 Kaszásdűlő
# 47            III.                 Mátyáshegy
# 48            III.               Mocsárosdűlő
# 49            III.              Óbudai-sziget
# 50            III.                 Remetehegy
# 51            III.                 Rómaifürdő
# 52            III.               Solymárvölgy
# 53            III.                  Szépvölgy
# 54            III.                  Táborhegy
# 55            III.                Testvérhegy
# 56            III.                    Törökkő
# 57            III.                   Ürömhegy
# 58            III.                     Újlak.
# 59             IV.                     Újpest
# 60             IV.                     Megyer
# 61             IV.            Káposztásmegyer
# 62             IV.                 Székesdűlő
# 63             IV.               Istvántelek.
# 64              V.                 Inner City
# 65              V.                 Lipótváros
# 66             VI.                 Terézváros
# 67            VII.              Erzsébetváros
# 68           VIII.                Józsefváros
# 69           VIII.                Kerepesdűlő
# 70           VIII.           Tisztviselőtelep
# 71             IX.                Ferencváros
# 72             IX.                Gubacsidűlő
# 73             IX.    József Attila-lakótelep
# 74              X.                 Felsőrákos
# 75              X.                   Gyárdűlő
# 76              X.             Keresztúridűlő
# 77              X.          Kőbánya-Kertváros
# 78             XI.                Albertfalva
# 79             XI.                     Dobogó
# 80             XI.                  Gazdagrét
# 81             XI.                Gellérthegy
# 82             XI.                  Hosszúrét
# 83             XI.                 Kamaraerdő
# 84             XI.                  Kelenföld
# 85             XI.                 Kelenvölgy
# 86             XI.                  Kőérberek
# 87             XI.                 Lágymányos
# 88             XI.                  Madárhegy
# 89             XI.                     Őrmező
# 90             XI.                      Örsöd
# 91             XI.                  Péterhegy
# 92             XI.              Pösingermajor
# 93             XI.                      Sasad
# 94             XI.                    Sashegy
# 95             XI.                 Spanyolrét
# 96             XI.                      Tabán
# 97            XII.              Budakeszierdő
# 98            XII.                 Csillebérc
# 99            XII.                  Farkasrét
# 100           XII.                Farkasvölgy
# 101           XII.                  Istenhegy
# 102           XII.                  Jánoshegy
# 103           XII.                Kissvábhegy
# 104           XII.             Krisztinaváros
# 105           XII.                   Kútvölgy
# 106           XII.                    Magasút
# 107           XII.                 Mártonhegy
# 108           XII.                 Németvölgy
# 109           XII.                  Orbánhegy
# 110           XII.                    Sashegy
# 111           XII.                   Svábhegy
# 112           XII.              Széchenyihegy
# 113           XII.                  Virányos.
# 114          XIII.               Újlipótváros
# 115          XIII.                 Angyalföld
# 116          XIII.                   Vizafogó
# 117          XIII.                  Népsziget
# 118          XIII.   Göncz Árpád városközpont
# 119           XIV.                  Alsórákos
# 120           XIV.                Herminamező
# 121           XIV.                 Istvánmező
# 122           XIV.                   Kiszugló
# 123           XIV.                  Nagyzugló
# 124           XIV.                 Rákosfalva
# 125           XIV.                    Törökőr
# 126           XIV.                  City Park
# 127            XV.                Rákospalota
# 128            XV.                 Pestújhely
# 129            XV.                   Újpalota
# 130           XVI.                 Mátyásföld
# 131           XVI.                   Sashalom
# 132           XVI.                    Cinkota
# 133           XVI.           Rákosszentmihály
# 134           XVI.                  Árpádföld
# 135           XVI.             Kisszentmihály
# 136           XVI.                 Ilonatelep
# 137           XVI.                 Petőfikert
# 138           XVI.              Nagyiccetelep
# 139           XVI.           Szentgyörgytelep
# 140           XVI.             Szabadságtelep
# 141           XVI.                Huszkatelep
# 142          XVII.             Rákoskeresztúr
# 143          XVII.                 Rákoscsaba
# 144          XVII.         Rákoscsaba-Újtelep
# 145          XVII.                 Rákosliget
# 146          XVII.                  Rákoshegy
# 147          XVII.                  Rákoskert
# 148          XVII.            Akadémiaújtelep
# 149          XVII.                  Madárdomb
# 150          XVII.          Régiakadémiatelep
# 151         XVIII.            Pestszentlőrinc
# 152         XVIII.              Pestszentimre
# 153   XIX. kerület                    Kispest
# 154   XIX. kerület               Wekerletelep
# 155            XX.              Gubacsipuszta
# 156            XX.               Kossuthfalva
# 157            XX.              Pacsirtatelep
# 158            XX.               Pesterzsébet
# 159            XX.    Pesterzsébet-Szabótelep
# 160           XXI.                     Csepel
# 161          XXII.                 Budatétény
# 162          XXII.                 Nagytétény
# 163          XXII.                    Budafok
# 164         XXIII.                   Soroksár
# 165   non-district              Margit-sziget

# %% [markdown]
# In case of inappropriate values for the geolocator, I need to drop and refill some of the records with proper format.

# %%
added_df.drop(axis=0, index=4, inplace=True) #dropping southern Víziváros I. in case of inappropriate value
added_df.drop(axis=0, index=110, inplace=True) #dropping Sashegy XII. in case of inappropriate value
added_df.drop(axis=0, index=104, inplace=True) #dropping Krisztinaváros XII. in case of inappropriate value
added_df.drop(axis=0, index=165, inplace=True) #dropping Margit-sziget in case of inappropriate value
added_df.drop(axis=0, index=96, inplace=True) #dropping Tabán XI. in case of inappropriate value
added_df.drop(axis=0, index=2, inplace=True) #dropping Gellérthegy I. in case of inappropriate value
added_df.drop(axis=0, index=53, inplace=True) #dropping Szépvölgy III. in case of inappropriate value
added_df.drop(axis=0, index=36, inplace=True) #dropping northern Víziváros II. in case of inappropriate value, replaced
added_df.drop(axis=0, index=25, inplace=True) #dropping Petneházy-rét II. in case of inappropriate value, replaced
added_df.drop(axis=0, index=34, inplace=True) #dropping Újlak II. in case of inappropriate value
added_df.drop(axis=0, index=58, inplace=True) #dropping Újlak III. in case of inappropriate value, replaced
added_df.drop(axis=0, index=64, inplace=True) #dropping Inner City V. in case of inappropriate value, replaced
added_df.drop(axis=0, index=139, inplace=True) #dropping Szentgyörgytelep XVI. in case of inappropriate value, replaced
added_df.drop(axis=0, index=141, inplace=True) #dropping Huszkatelep XVI. in case of inappropriate value
added_df.drop(axis=0, index=159, inplace=True) #dropping Pesterzsébet-Szabótelep XX. in case of inappropriate value, replaced
added_df.reset_index(drop = True, inplace=True)

# %%
# added_df.replace(to_replace='northern Víziváros', value='Víziváros', inplace=True) is not working due to an internal error, 
# therefore I had to use something else

# data of for replacing the inapproriate values, tested with Nominatim
vizivaros={"DistrictNumber":"II.", "Neighborhood":"Víziváros"}
petnehazyret={"DistrictNumber":"II.", "Neighborhood":"Petneházyrét"}
ujlak={"DistrictNumber":"III.", "Neighborhood":"Újlak"}
belvaros={"DistrictNumber":"V.", "Neighborhood":"Belváros"}
szentgyorgytelep ={"DistrictNumber":"XVI.", "Neighborhood":"Szent György telep"}
szabotelep ={"DistrictNumber":"XX.", "Neighborhood":"Szabótelep"}

added_df=added_df.append(vizivaros, ignore_index=True)
added_df=added_df.append(petnehazyret, ignore_index=True)
added_df=added_df.append(ujlak, ignore_index=True)
added_df=added_df.append(belvaros, ignore_index=True)
added_df=added_df.append(szentgyorgytelep, ignore_index=True)
added_df=added_df.append(szabotelep, ignore_index=True)

# %% [markdown]
# At this point, we have the proper name for each neighborhood, the next step is to find the Geo locations (latitude and longitude values) for them. The following code is doing that perfectly, using Geopy python package.

# %%
addr_list = added_df.Neighborhood.to_list()
district_list = added_df.DistrictNumber.to_list()
lat_list = []
lon_list = []

geolocator = Nominatim(user_agent="cf_explorer")

for actual_address in range(len(addr_list)):
    location = geolocator.geocode(addr_list[actual_address])
    latitude = location.latitude
    longitude = location.longitude
    lat_list.append(latitude)
    lon_list.append(longitude)

added_df["Latitude"] = lat_list
added_df["Longitude"] = lon_list
added_df
# Out:
#     DistrictNumber               Neighborhood   Latitude  Longitude
# 0               I.                Buda Castle  47.495991  19.039801
# 1               I.                      Tabán  47.490893  19.042639
# 2               I.             Krisztinaváros  47.496865  19.029776
# 3              II.                   Adyliget  47.547550  18.938984
# 4              II.              Budakeszierdő  47.510273  18.951182
# 5              II.                  Budaliget  47.567579  18.940664
# 6              II.                   Csatárka  47.531525  19.002578
# 7              II.              Erzsébetliget  47.561714  18.967558
# 8              II.              Erzsébettelek  47.544978  18.957372
# 9              II.                   Felhévíz  47.517500  19.037039
# 10             II.                     Gercse  47.567464  18.985744
# 11             II.                 Hársakalja  47.551378  18.966541
# 12             II.                   Hárshegy  47.533536  18.958761
# 13             II.                 Hűvösvölgy  47.541159  18.963724
# 14             II.                      Kővár  47.557233  18.982032
# 15             II.                   Kurucles  47.523124  18.973697
# 16             II.                  Lipótmező  47.531448  18.975792
# 17             II.                Máriaremete  47.558807  18.945267
# 18             II.                       Nyék  47.535502  18.987766
# 19             II.                   Országút  47.511709  19.027287
# 20             II.                   Pálvölgy  47.534780  19.011878
# 21             II.                    Pasarét  47.520288  18.997372
# 22             II.         Pesthidegkút-Ófalu  47.569779  18.961257
# 23             II.            Remetekertváros  47.552031  18.956575
# 24             II.                     Rézmál  47.516672  19.019460
# 25             II.                  Rózsadomb  47.517329  19.028288
# 26             II.                 Szemlőhegy  47.524329  19.028179
# 27             II.                  Széphalom  47.560038  18.959638
# 28             II.                  Szépilona  47.519217  18.990449
# 29             II.                  Szépvölgy  47.541606  19.000581
# 30             II.                  Törökvész  47.522098  19.003083
# 31             II.                   Vérhalom  47.523980  19.015493
# 32             II.                   Zöldmál.  47.527225  19.015552
# 33            III.                      Óbuda  47.538592  19.039561
# 34            III.                   Aquincum  47.566302  19.047360
# 35            III.                  Aranyhegy  47.078725  21.960535
# 36            III.                Békásmegyer  47.599413  19.054996
# 37            III.                Csillaghegy  47.586163  19.050705
# 38            III.                  Csúcshegy  47.574214  18.994917
# 39            III.                Filatorigát  47.550666  19.045403
# 40            III.           Hármashatár-hegy  47.554997  18.998450
# 41            III.                 Kaszásdűlő  47.560958  19.038223
# 42            III.                 Mátyáshegy  47.533622  19.022806
# 43            III.               Mocsárosdűlő  47.573029  19.040075
# 44            III.              Óbudai-sziget  47.549104  19.053424
# 45            III.                 Remetehegy  47.540454  19.020446
# 46            III.                 Rómaifürdő  47.574838  19.056706
# 47            III.               Solymárvölgy  47.578406  19.001923
# 48            III.                  Táborhegy  46.985954  16.612621
# 49            III.                Testvérhegy  47.563934  19.013587
# 50            III.                    Törökkő  47.564414  19.027652
# 51            III.                   Ürömhegy  47.581481  19.020033
# 52             IV.                     Újpest  47.576169  19.095508
# 53             IV.                     Megyer  47.061119  17.192334
# 54             IV.            Káposztásmegyer  47.594972  19.107603
# 55             IV.                 Székesdűlő  47.610108  19.106231
# 56             IV.               Istvántelek.  47.550218  19.104467
# 57              V.                 Lipótváros  47.504543  19.050380
# 58             VI.                 Terézváros  47.509494  19.065323
# 59            VII.              Erzsébetváros  47.502814  19.077359
# 60           VIII.                Józsefváros  47.490595  19.087340
# 61           VIII.                Kerepesdűlő  47.497376  19.091670
# 62           VIII.           Tisztviselőtelep  47.480674  19.097577
# 63             IX.                Ferencváros  47.465356  19.090356
# 64             IX.                Gubacsidűlő  47.450265  19.097134
# 65             IX.    József Attila-lakótelep  47.670225  17.662281
# 66              X.                 Felsőrákos  47.495210  19.174455
# 67              X.                   Gyárdűlő  47.475337  19.122575
# 68              X.             Keresztúridűlő  47.474090  19.186396
# 69              X.          Kőbánya-Kertváros  47.482696  19.200295
# 70             XI.                Albertfalva  47.447294  19.034295
# 71             XI.                     Dobogó  47.458998  19.004162
# 72             XI.                  Gazdagrét  47.470116  18.998675
# 73             XI.                Gellérthegy  47.484565  19.038769
# 74             XI.                  Hosszúrét  47.466102  18.997380
# 75             XI.                 Kamaraerdő  47.430066  18.986924
# 76             XI.                  Kelenföld  47.464299  19.020616
# 77             XI.                 Kelenvölgy  47.447778  19.024388
# 78             XI.                  Kőérberek  47.441477  18.995811
# 79             XI.                 Lágymányos  47.474755  19.055500
# 80             XI.                  Madárhegy  47.467738  18.988588
# 81             XI.                     Őrmező  48.874660  21.833769
# 82             XI.                      Örsöd  47.460295  18.986917
# 83             XI.                  Péterhegy  47.448714  19.011147
# 84             XI.              Pösingermajor  47.475565  18.980215
# 85             XI.                      Sasad  47.476076  19.006443
# 86             XI.                    Sashegy  47.480720  19.020026
# 87             XI.                 Spanyolrét  47.466288  18.982352
# 88            XII.              Budakeszierdő  47.510273  18.951182
# 89            XII.                 Csillebérc  47.488939  18.965693
# 90            XII.                  Farkasrét  47.484301  18.998835
# 91            XII.                Farkasvölgy  47.483441  18.988085
# 92            XII.                  Istenhegy  47.504135  18.999822
# 93            XII.                  Jánoshegy  47.519317  18.964888
# 94            XII.                Kissvábhegy  47.502268  19.012569
# 95            XII.                   Kútvölgy  47.509419  18.990725
# 96            XII.                    Magasút  47.480127  18.986517
# 97            XII.                 Mártonhegy  47.490261  19.001692
# 98            XII.                 Németvölgy  47.489525  19.017843
# 99            XII.                  Orbánhegy  47.496212  19.005486
# 100           XII.                   Svábhegy  47.502097  18.979497
# 101           XII.              Széchenyihegy  47.491250  18.984226
# 102           XII.                  Virányos.  47.514325  18.989610
# 103          XIII.               Újlipótváros  47.518041  19.054319
# 104          XIII.                 Angyalföld  47.550222  19.089510
# 105          XIII.                   Vizafogó  47.536914  19.064326
# 106          XIII.                  Népsziget  47.560434  19.072485
# 107          XIII.   Göncz Árpád városközpont  47.532753  19.066821
# 108           XIV.                  Alsórákos  47.525178  19.128280
# 109           XIV.                Herminamező  47.517972  19.098200
# 110           XIV.                 Istvánmező  47.507550  19.096480
# 111           XIV.                   Kiszugló  47.515028  19.114763
# 112           XIV.                  Nagyzugló  47.508150  19.126143
# 113           XIV.                 Rákosfalva  47.593337  24.025315
# 114           XIV.                    Törökőr  47.507438  19.111503
# 115           XIV.                  City Park  47.514868  19.084368
# 116            XV.                Rákospalota  47.563437  19.136502
# 117            XV.                 Pestújhely  47.537954  19.129764
# 118            XV.                   Újpalota  47.537794  19.145720
# 119           XVI.                 Mátyásföld  47.505783  19.208640
# 120           XVI.                   Sashalom  47.509815  19.177627
# 121           XVI.                    Cinkota  47.522284  19.230073
# 122           XVI.           Rákosszentmihály  47.527241  19.170336
# 123           XVI.                  Árpádföld  47.533133  19.198560
# 124           XVI.             Kisszentmihály  47.539645  19.179924
# 125           XVI.                 Ilonatelep  47.526665  19.233516
# 126           XVI.                 Petőfikert  47.508550  19.216607
# 127           XVI.              Nagyiccetelep  47.507354  19.184775
# 128           XVI.             Szabadságtelep  47.528416  21.652983
# 129          XVII.             Rákoskeresztúr  47.478841  19.246234
# 130          XVII.                 Rákoscsaba  47.480440  19.299117
# 131          XVII.         Rákoscsaba-Újtelep  47.487681  19.272507
# 132          XVII.                 Rákosliget  47.488941  19.259332
# 133          XVII.                  Rákoshegy  47.460958  19.241627
# 134          XVII.                  Rákoskert  47.465927  19.287958
# 135          XVII.            Akadémiaújtelep  47.481613  19.219526
# 136          XVII.                  Madárdomb  47.477217  19.232710
# 137          XVII.          Régiakadémiatelep  47.489491  19.247598
# 138         XVIII.            Pestszentlőrinc  47.455170  19.181257
# 139         XVIII.              Pestszentimre  47.403114  19.187456
# 140   XIX. kerület                    Kispest  47.448441  19.146518
# 141   XIX. kerület               Wekerletelep  47.455787  19.125910
# 142            XX.              Gubacsipuszta  47.428278  19.137171
# 143            XX.               Kossuthfalva  47.439170  19.123285
# 144            XX.              Pacsirtatelep  47.424419  19.119983
# 145            XX.               Pesterzsébet  47.433396  19.120921
# 146           XXI.                     Csepel  47.424317  19.069214
# 147          XXII.                 Budatétény  47.417128  19.010657
# 148          XXII.                 Nagytétény  47.397568  18.985958
# 149          XXII.                    Budafok  47.427530  19.026078
# 150         XXIII.                   Soroksár  47.389405  19.144158
# 151            II.                  Víziváros  47.507143  19.034517
# 152            II.               Petneházyrét  47.537211  18.941116
# 153           III.                      Újlak  48.526824  21.741507
# 154             V.                   Belváros  47.491918  19.054694
# 155           XVI.         Szent György telep  47.534691  19.169229
# 156            XX.                 Szabótelep  47.441885  19.129044

# %% [markdown]
# Now, we have all the proper names, latitude and longitude values for each neighborhood in Budapest, Hungary. The next step is to first, check the coordinates of Budapest with the geolocator class object, and then, we can create a map, to visualize our insights later.

# %%
#Checking the coordinates of Budapest, Hungary for creating a map
name_bud = "Budapest, Hungary"

location_bud = geolocator.geocode(name_bud)
lat_bud = location_bud.latitude
lon_bud = location_bud.longitude

print('The geograpical coordinate of Budapest are {}, {}.'.format(lat_bud, lon_bud))
print('Coordinate transformation check')
print('-------------------------------')
print('Budapest center longitude={}, latitude={}'.format(lon_bud, lat_bud))
x, y = lonlat_to_xy(lon_bud, lat_bud)
print('Budapest center UTM X={}, Y={}'.format(x, y))
lo, la = xy_to_lonlat(x, y)
print('Budapest center longitude={}, latitude={}'.format(lo, la))
# Out:
# The geograpical coordinate of Budapest are 47.4979937, 19.0403594.
# Coordinate transformation check
# -------------------------------
# Budapest center longitude=19.0403594, latitude=47.4979937
# Budapest center UTM X=804283.1088846511, Y=5268422.807057823
# Budapest center longitude=19.0403594, latitude=47.49799370000001
# F:\Programs\Anaconda\lib\site-packages\ipykernel_launcher.py:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   # Remove the CWD from sys.path while we load stuff.
# F:\Programs\Anaconda\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   after removing the cwd from sys.path.

# %%
# create map of Manhattan using latitude and longitude values
map_budapest = folium.Map(location=[lat_bud, lon_bud], zoom_start=11)

# add markers to map
for lat, lng, label in zip(added_df['Latitude'], added_df['Longitude'], added_df['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_budapest)  
    
map_budapest
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Next step is to create the dataset for the Crossfit Boxes of Budapest. Since there is no available data, I needed to create my own.

# %%
#I had to create my own dataset for the Crossfit boxes in Budapest, because there was no accessable table regarding this
cf_list_bud = ["Crossfit Budapest", "Reebok Crossfit Duna", "Crossfit Tesseract", "Crossfit Everybody", 
               "Crossfit Mayfly", "Crossfit BBros", "Crossfit BBros 2", "Crossfit Grund", "Crossfit Bloodfit", 
              "Crossfit Glasshouse", "Crossfit Újbuda", "Bulls Park Crossfit", "Crossfit Corvinus"]
cf_bud_addr = ["Pillangó Park 8", "Hajógyári sziget 130", "Mexikói út 25", "Borszék köz 1", 
               "Kondorfa utca 6", "Zichy Géza utca 12", "Márton utca 4", "Hegedűs Gyula utca 14", "Tüzér utca 46",
              "Nándorfejérvári út 40", "Barázda utca 1", "Sopron út 9", "Gyömrői út 118"]
cf_bud_distr = ["XIV.", "III.", "XIV.", "XI.", "XI.", "XIV.", "IX.", "XIII.", "XIII.", "XI.", "XI.", "XI.", "XVIII"]
cf_df_col_list = ["DistrictNumber", "CrossfitBoxName", "Address", "Latitude", "Longitude"]
cf_df = pd.DataFrame(columns = cf_df_col_list)
cf_df.DistrictNumber = cf_bud_distr
cf_df.CrossfitBoxName = cf_list_bud
cf_df.Address = cf_bud_addr
cf_df
# Out:
#    DistrictNumber       CrossfitBoxName                Address Latitude  \
# 0            XIV.     Crossfit Budapest        Pillangó Park 8      NaN
# 1            III.  Reebok Crossfit Duna   Hajógyári sziget 130      NaN
# 2            XIV.    Crossfit Tesseract          Mexikói út 25      NaN
# 3             XI.    Crossfit Everybody          Borszék köz 1      NaN
# 4             XI.       Crossfit Mayfly        Kondorfa utca 6      NaN
# 5            XIV.        Crossfit BBros     Zichy Géza utca 12      NaN
# 6             IX.      Crossfit BBros 2          Márton utca 4      NaN
# 7           XIII.        Crossfit Grund  Hegedűs Gyula utca 14      NaN
# 8           XIII.     Crossfit Bloodfit          Tüzér utca 46      NaN
# 9             XI.   Crossfit Glasshouse  Nándorfejérvári út 40      NaN
# 10            XI.       Crossfit Újbuda         Barázda utca 1      NaN
# 11            XI.   Bulls Park Crossfit            Sopron út 9      NaN
# 12          XVIII     Crossfit Corvinus         Gyömrői út 118      NaN
#
#    Longitude
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10       NaN
# 11       NaN
# 12       NaN

# %%
cf_bud_district = ["XIV.", "III.", "XIV.", "XI.", "XI.", "XIV.", "IX.", "XIII.", "XIII.", "XI.", "XI.", "XI.", "XVIII"]
cf_bud_address = ["Pillangó Park 8", "Hajógyári sziget 130", "Mexikói út 25", "Borszék köz 1", 
               "Kondorfa utca 6", "Zichy Géza utca 12", "Márton utca 4", "Hegedűs Gyula utca 14", "Tüzér utca 46",
              "Nándorfejérvári út 40", "Barázda utca 1", "Sopron út 9", "Gyömrői út 118"]

cf_lat_list = []
cf_lon_list = []
cf_loc = []

for actual_address in range(len(cf_bud_address)):
     cf_loc.append("{}, Budapest, Hungary".format(cf_bud_address[actual_address]))
    
geolocator = Nominatim(user_agent="hun_explorer")

for actual_address in range(len(cf_loc)):
    location = geolocator.geocode(cf_loc[actual_address])
    latitude = location.latitude
    longitude = location.longitude
    cf_lat_list.append(latitude)
    cf_lon_list.append(longitude)
    
    

cf_df["Latitude"] = cf_lat_list
cf_df["Longitude"] = cf_lon_list
cf_df
# Out:
#    DistrictNumber       CrossfitBoxName                Address   Latitude  \
# 0            XIV.     Crossfit Budapest        Pillangó Park 8  47.505122
# 1            III.  Reebok Crossfit Duna   Hajógyári sziget 130  47.554403
# 2            XIV.    Crossfit Tesseract          Mexikói út 25  47.519416
# 3             XI.    Crossfit Everybody          Borszék köz 1  47.458482
# 4             XI.       Crossfit Mayfly        Kondorfa utca 6  47.453356
# 5            XIV.        Crossfit BBros     Zichy Géza utca 12  47.509135
# 6             IX.      Crossfit BBros 2          Márton utca 4  47.476906
# 7           XIII.        Crossfit Grund  Hegedűs Gyula utca 14  47.514103
# 8           XIII.     Crossfit Bloodfit          Tüzér utca 46  47.524592
# 9             XI.   Crossfit Glasshouse  Nándorfejérvári út 40  47.461456
# 10            XI.       Crossfit Újbuda         Barázda utca 1  47.457383
# 11            XI.   Bulls Park Crossfit            Sopron út 9  47.462218
# 12          XVIII     Crossfit Corvinus         Gyömrői út 118  47.456731
#
#     Longitude
# 0   19.121754
# 1   19.059319
# 2   19.090593
# 3   19.026134
# 4   19.043747
# 5   19.092250
# 6   19.077625
# 7   19.053601
# 8   19.070284
# 9   19.045858
# 10  19.045210
# 11  19.044000
# 12  19.182213

# %% [markdown]
# Adding the Crossfit Boxes into our previoulsy created map, to see their position.

# %%
# add markers to map
for lat, lng, label in zip(cf_df['Latitude'], cf_df['Longitude'], cf_df['CrossfitBoxName']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='red',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_budapest)
    folium.Circle([lat, lng], radius=500, color='white', fill=False).add_to(map_budapest) 
    
map_budapest
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Now, we see that there are plenty of Crossfit Boxes among Budapest city, also they trying to follow a pattern. Each Box tries to be as close to the inner town as they can, also they tries to position themselves in the crowded areas. To fully understand their behavior and segment the neighborhoods, we need to create one final dataset.

# %% [markdown]
# Concatenating these two separate datasets into one greater will create our final dataset.

# %%
#Concat the two venue list to see how the clustering performs then
bp_df = added_df
bud_cf_df = cf_df
bud_cf_df.rename(columns={'CrossfitBoxName':'Neighborhood'}, inplace=True)
bud_cf_df.drop(labels='Address',axis=1, inplace=True)
total_df = pd.concat([bp_df,bud_cf_df], ignore_index=True)
total_df
# Out:
#     DistrictNumber               Neighborhood   Latitude  Longitude
# 0               I.                Buda Castle  47.495991  19.039801
# 1               I.                      Tabán  47.490893  19.042639
# 2               I.             Krisztinaváros  47.496865  19.029776
# 3              II.                   Adyliget  47.547550  18.938984
# 4              II.              Budakeszierdő  47.510273  18.951182
# 5              II.                  Budaliget  47.567579  18.940664
# 6              II.                   Csatárka  47.531525  19.002578
# 7              II.              Erzsébetliget  47.561714  18.967558
# 8              II.              Erzsébettelek  47.544978  18.957372
# 9              II.                   Felhévíz  47.517500  19.037039
# 10             II.                     Gercse  47.567464  18.985744
# 11             II.                 Hársakalja  47.551378  18.966541
# 12             II.                   Hárshegy  47.533536  18.958761
# 13             II.                 Hűvösvölgy  47.541159  18.963724
# 14             II.                      Kővár  47.557233  18.982032
# 15             II.                   Kurucles  47.523124  18.973697
# 16             II.                  Lipótmező  47.531448  18.975792
# 17             II.                Máriaremete  47.558807  18.945267
# 18             II.                       Nyék  47.535502  18.987766
# 19             II.                   Országút  47.511709  19.027287
# 20             II.                   Pálvölgy  47.534780  19.011878
# 21             II.                    Pasarét  47.520288  18.997372
# 22             II.         Pesthidegkút-Ófalu  47.569779  18.961257
# 23             II.            Remetekertváros  47.552031  18.956575
# 24             II.                     Rézmál  47.516672  19.019460
# 25             II.                  Rózsadomb  47.517329  19.028288
# 26             II.                 Szemlőhegy  47.524329  19.028179
# 27             II.                  Széphalom  47.560038  18.959638
# 28             II.                  Szépilona  47.519217  18.990449
# 29             II.                  Szépvölgy  47.541606  19.000581
# 30             II.                  Törökvész  47.522098  19.003083
# 31             II.                   Vérhalom  47.523980  19.015493
# 32             II.                   Zöldmál.  47.527225  19.015552
# 33            III.                      Óbuda  47.538592  19.039561
# 34            III.                   Aquincum  47.566302  19.047360
# 35            III.                  Aranyhegy  47.078725  21.960535
# 36            III.                Békásmegyer  47.599413  19.054996
# 37            III.                Csillaghegy  47.586163  19.050705
# 38            III.                  Csúcshegy  47.574214  18.994917
# 39            III.                Filatorigát  47.550666  19.045403
# 40            III.           Hármashatár-hegy  47.554997  18.998450
# 41            III.                 Kaszásdűlő  47.560958  19.038223
# 42            III.                 Mátyáshegy  47.533622  19.022806
# 43            III.               Mocsárosdűlő  47.573029  19.040075
# 44            III.              Óbudai-sziget  47.549104  19.053424
# 45            III.                 Remetehegy  47.540454  19.020446
# 46            III.                 Rómaifürdő  47.574838  19.056706
# 47            III.               Solymárvölgy  47.578406  19.001923
# 48            III.                  Táborhegy  46.985954  16.612621
# 49            III.                Testvérhegy  47.563934  19.013587
# 50            III.                    Törökkő  47.564414  19.027652
# 51            III.                   Ürömhegy  47.581481  19.020033
# 52             IV.                     Újpest  47.576169  19.095508
# 53             IV.                     Megyer  47.061119  17.192334
# 54             IV.            Káposztásmegyer  47.594972  19.107603
# 55             IV.                 Székesdűlő  47.610108  19.106231
# 56             IV.               Istvántelek.  47.550218  19.104467
# 57              V.                 Lipótváros  47.504543  19.050380
# 58             VI.                 Terézváros  47.509494  19.065323
# 59            VII.              Erzsébetváros  47.502814  19.077359
# 60           VIII.                Józsefváros  47.490595  19.087340
# 61           VIII.                Kerepesdűlő  47.497376  19.091670
# 62           VIII.           Tisztviselőtelep  47.480674  19.097577
# 63             IX.                Ferencváros  47.465356  19.090356
# 64             IX.                Gubacsidűlő  47.450265  19.097134
# 65             IX.    József Attila-lakótelep  47.670225  17.662281
# 66              X.                 Felsőrákos  47.495210  19.174455
# 67              X.                   Gyárdűlő  47.475337  19.122575
# 68              X.             Keresztúridűlő  47.474090  19.186396
# 69              X.          Kőbánya-Kertváros  47.482696  19.200295
# 70             XI.                Albertfalva  47.447294  19.034295
# 71             XI.                     Dobogó  47.458998  19.004162
# 72             XI.                  Gazdagrét  47.470116  18.998675
# 73             XI.                Gellérthegy  47.484565  19.038769
# 74             XI.                  Hosszúrét  47.466102  18.997380
# 75             XI.                 Kamaraerdő  47.430066  18.986924
# 76             XI.                  Kelenföld  47.464299  19.020616
# 77             XI.                 Kelenvölgy  47.447778  19.024388
# 78             XI.                  Kőérberek  47.441477  18.995811
# 79             XI.                 Lágymányos  47.474755  19.055500
# 80             XI.                  Madárhegy  47.467738  18.988588
# 81             XI.                     Őrmező  48.874660  21.833769
# 82             XI.                      Örsöd  47.460295  18.986917
# 83             XI.                  Péterhegy  47.448714  19.011147
# 84             XI.              Pösingermajor  47.475565  18.980215
# 85             XI.                      Sasad  47.476076  19.006443
# 86             XI.                    Sashegy  47.480720  19.020026
# 87             XI.                 Spanyolrét  47.466288  18.982352
# 88            XII.              Budakeszierdő  47.510273  18.951182
# 89            XII.                 Csillebérc  47.488939  18.965693
# 90            XII.                  Farkasrét  47.484301  18.998835
# 91            XII.                Farkasvölgy  47.483441  18.988085
# 92            XII.                  Istenhegy  47.504135  18.999822
# 93            XII.                  Jánoshegy  47.519317  18.964888
# 94            XII.                Kissvábhegy  47.502268  19.012569
# 95            XII.                   Kútvölgy  47.509419  18.990725
# 96            XII.                    Magasút  47.480127  18.986517
# 97            XII.                 Mártonhegy  47.490261  19.001692
# 98            XII.                 Németvölgy  47.489525  19.017843
# 99            XII.                  Orbánhegy  47.496212  19.005486
# 100           XII.                   Svábhegy  47.502097  18.979497
# 101           XII.              Széchenyihegy  47.491250  18.984226
# 102           XII.                  Virányos.  47.514325  18.989610
# 103          XIII.               Újlipótváros  47.518041  19.054319
# 104          XIII.                 Angyalföld  47.550222  19.089510
# 105          XIII.                   Vizafogó  47.536914  19.064326
# 106          XIII.                  Népsziget  47.560434  19.072485
# 107          XIII.   Göncz Árpád városközpont  47.532753  19.066821
# 108           XIV.                  Alsórákos  47.525178  19.128280
# 109           XIV.                Herminamező  47.517972  19.098200
# 110           XIV.                 Istvánmező  47.507550  19.096480
# 111           XIV.                   Kiszugló  47.515028  19.114763
# 112           XIV.                  Nagyzugló  47.508150  19.126143
# 113           XIV.                 Rákosfalva  47.593337  24.025315
# 114           XIV.                    Törökőr  47.507438  19.111503
# 115           XIV.                  City Park  47.514868  19.084368
# 116            XV.                Rákospalota  47.563437  19.136502
# 117            XV.                 Pestújhely  47.537954  19.129764
# 118            XV.                   Újpalota  47.537794  19.145720
# 119           XVI.                 Mátyásföld  47.505783  19.208640
# 120           XVI.                   Sashalom  47.509815  19.177627
# 121           XVI.                    Cinkota  47.522284  19.230073
# 122           XVI.           Rákosszentmihály  47.527241  19.170336
# 123           XVI.                  Árpádföld  47.533133  19.198560
# 124           XVI.             Kisszentmihály  47.539645  19.179924
# 125           XVI.                 Ilonatelep  47.526665  19.233516
# 126           XVI.                 Petőfikert  47.508550  19.216607
# 127           XVI.              Nagyiccetelep  47.507354  19.184775
# 128           XVI.             Szabadságtelep  47.528416  21.652983
# 129          XVII.             Rákoskeresztúr  47.478841  19.246234
# 130          XVII.                 Rákoscsaba  47.480440  19.299117
# 131          XVII.         Rákoscsaba-Újtelep  47.487681  19.272507
# 132          XVII.                 Rákosliget  47.488941  19.259332
# 133          XVII.                  Rákoshegy  47.460958  19.241627
# 134          XVII.                  Rákoskert  47.465927  19.287958
# 135          XVII.            Akadémiaújtelep  47.481613  19.219526
# 136          XVII.                  Madárdomb  47.477217  19.232710
# 137          XVII.          Régiakadémiatelep  47.489491  19.247598
# 138         XVIII.            Pestszentlőrinc  47.455170  19.181257
# 139         XVIII.              Pestszentimre  47.403114  19.187456
# 140   XIX. kerület                    Kispest  47.448441  19.146518
# 141   XIX. kerület               Wekerletelep  47.455787  19.125910
# 142            XX.              Gubacsipuszta  47.428278  19.137171
# 143            XX.               Kossuthfalva  47.439170  19.123285
# 144            XX.              Pacsirtatelep  47.424419  19.119983
# 145            XX.               Pesterzsébet  47.433396  19.120921
# 146           XXI.                     Csepel  47.424317  19.069214
# 147          XXII.                 Budatétény  47.417128  19.010657
# 148          XXII.                 Nagytétény  47.397568  18.985958
# 149          XXII.                    Budafok  47.427530  19.026078
# 150         XXIII.                   Soroksár  47.389405  19.144158
# 151            II.                  Víziváros  47.507143  19.034517
# 152            II.               Petneházyrét  47.537211  18.941116
# 153           III.                      Újlak  48.526824  21.741507
# 154             V.                   Belváros  47.491918  19.054694
# 155           XVI.         Szent György telep  47.534691  19.169229
# 156            XX.                 Szabótelep  47.441885  19.129044
# 157           XIV.          Crossfit Budapest  47.505122  19.121754
# 158           III.       Reebok Crossfit Duna  47.554403  19.059319
# 159           XIV.         Crossfit Tesseract  47.519416  19.090593
# 160            XI.         Crossfit Everybody  47.458482  19.026134
# 161            XI.            Crossfit Mayfly  47.453356  19.043747
# 162           XIV.             Crossfit BBros  47.509135  19.092250
# 163            IX.           Crossfit BBros 2  47.476906  19.077625
# 164          XIII.             Crossfit Grund  47.514103  19.053601
# 165          XIII.          Crossfit Bloodfit  47.524592  19.070284
# 166            XI.        Crossfit Glasshouse  47.461456  19.045858
# 167            XI.            Crossfit Újbuda  47.457383  19.045210
# 168            XI.        Bulls Park Crossfit  47.462218  19.044000
# 169          XVIII          Crossfit Corvinus  47.456731  19.182213

# %% [markdown]
# Visualizing the dataset will give us some insights. First of all, we can see exactly where these neighborhoods are, therefore we can check their population distribution among the city.

# %%
# create map of Budapest using latitude and longitude values
map_budapest = folium.Map(location=[lat_bud, lon_bud], zoom_start=11)

# add markers to map
for lat, lng, label in zip(total_df['Latitude'], total_df['Longitude'], total_df['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_budapest)  
    
map_budapest
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Every preparation has made to start working on the model feed data. I used Foursquare data to create different clusters for the neighborhoods based on the user feedbacks on them.

# %% [markdown]
# First, I need the nearby venues, then to make them into the proper format. After that I get the most common venues and then create a dataframe for them.

# %%
CLIENT_ID = '' # your Foursquare ID
CLIENT_SECRET = '' # your Foursquare Secret
VERSION = '' # Foursquare API version

#print('Your credentails:')
#print('CLIENT_ID: ' + CLIENT_ID)
#print('CLIENT_SECRET:' + CLIENT_SECRET)

def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

total_data = total_df
LIMIT = 500
total_bp_venues = getNearbyVenues(names=total_data['Neighborhood'],
                                   latitudes=total_data['Latitude'],
                                   longitudes=total_data['Longitude']
                                  )

print(total_bp_venues.shape)
total_bp_venues.head()

total_bp_venues.groupby('Neighborhood').count()
print('There are {} uniques categories.'.format(len(total_bp_venues['Venue Category'].unique())))
# Out:
# Buda Castle
#  Tabán
#  Krisztinaváros
# Adyliget
#  Budakeszierdő
#  Budaliget
#  Csatárka
#  Erzsébetliget
#  Erzsébettelek
#  Felhévíz
#  Gercse
#  Hársakalja
#  Hárshegy
#  Hűvösvölgy
#  Kővár
#  Kurucles
#  Lipótmező
#  Máriaremete
#  Nyék
#  Országút
#  Pálvölgy
#  Pasarét
#  Pesthidegkút-Ófalu
#  Remetekertváros
#  Rézmál
#  Rózsadomb
#  Szemlőhegy
#  Széphalom
#  Szépilona
#  Szépvölgy
#  Törökvész
#  Vérhalom
#  Zöldmál.
# Óbuda
#  Aquincum
#  Aranyhegy
#  Békásmegyer
#  Csillaghegy
#  Csúcshegy
#  Filatorigát
#  Hármashatár-hegy
#  Kaszásdűlő
#  Mátyáshegy
#  Mocsárosdűlő
#  Óbudai-sziget
#  Remetehegy
#  Rómaifürdő
#  Solymárvölgy
#  Táborhegy
#  Testvérhegy
#  Törökkő
#  Ürömhegy
# Újpest
#  Megyer
#  Káposztásmegyer
#  Székesdűlő
#  Istvántelek.
#  Lipótváros
# Terézváros
# Erzsébetváros
# Józsefváros
#  Kerepesdűlő
#  Tisztviselőtelep
# Ferencváros
#  Gubacsidűlő
#  József Attila-lakótelep
# Felsőrákos
#  Gyárdűlő
#  Keresztúridűlő
#  Kőbánya-Kertváros
# Albertfalva
#  Dobogó
#  Gazdagrét
#  Gellérthegy
#  Hosszúrét
#  Kamaraerdő
#  Kelenföld
#  Kelenvölgy
#  Kőérberek
#  Lágymányos
#  Madárhegy
#  Őrmező
#  Örsöd
#  Péterhegy
#  Pösingermajor
#  Sasad
#  Sashegy
#  Spanyolrét
# Budakeszierdő
#  Csillebérc
#  Farkasrét
#  Farkasvölgy
#  Istenhegy
#  Jánoshegy
#  Kissvábhegy
#  Kútvölgy
#  Magasút
#  Mártonhegy
#  Németvölgy
#  Orbánhegy
#  Svábhegy
#  Széchenyihegy
#  Virányos.
# Újlipótváros
#  Angyalföld
#  Vizafogó
#  Népsziget
#  Göncz Árpád városközpont
# Alsórákos
#  Herminamező
#  Istvánmező
#  Kiszugló
#  Nagyzugló
#  Rákosfalva
#  Törökőr
#  City Park
# Rákospalota
#  Pestújhely
#  Újpalota
# Mátyásföld
#  Sashalom
#  Cinkota
#  Rákosszentmihály
#  Árpádföld
#  Kisszentmihály
#  Ilonatelep
#  Petőfikert
#  Nagyiccetelep
#  Szabadságtelep
# Rákoskeresztúr
#  Rákoscsaba
#  Rákoscsaba-Újtelep
#  Rákosliget
#  Rákoshegy
#  Rákoskert
#  Akadémiaújtelep
#  Madárdomb
#  Régiakadémiatelep
# Pestszentlőrinc
#  Pestszentimre
# Kispest
#  Wekerletelep
# Gubacsipuszta
#  Kossuthfalva
#  Pacsirtatelep
#  Pesterzsébet
# Csepel
# Budatétény
#  Nagytétény
#  Budafok
# Soroksár
# Víziváros
# Petneházyrét
# Újlak
# Belváros
# Szent György telep
# Szabótelep
# Crossfit Budapest
# Reebok Crossfit Duna
# Crossfit Tesseract
# Crossfit Everybody
# Crossfit Mayfly
# Crossfit BBros
# Crossfit BBros 2
# Crossfit Grund
# Crossfit Bloodfit
# Crossfit Glasshouse
# Crossfit Újbuda
# Bulls Park Crossfit
# Crossfit Corvinus
# (2436, 7)
# There are 280 uniques categories.

# %%
# one hot encoding
total_bp_onehot = pd.get_dummies(total_bp_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
total_bp_onehot['Neighborhood'] = total_bp_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [total_bp_onehot.columns[-1]] + list(total_bp_onehot.columns[:-1])
total_bp_onehot = total_bp_onehot[fixed_columns]

total_bp_grouped = total_bp_onehot.groupby('Neighborhood').mean().reset_index()

num_top_venues = 5

for hood in total_bp_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = total_bp_grouped[total_bp_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ---- Akadémiaújtelep----
#                   venue  freq
# 0                Bakery  0.25
# 1  Fast Food Restaurant  0.25
# 2              Pharmacy  0.25
# 3                  Park  0.25
# 4           Yoga Studio  0.00
#
#
# ---- Angyalföld----
#                    venue  freq
# 0                    Gym  0.25
# 1     Light Rail Station  0.25
# 2           Tram Station  0.25
# 3                 Bistro  0.25
# 4  Outdoors & Recreation  0.00
#
#
# ---- Aquincum----
#            venue  freq
# 0  Historic Site  0.20
# 1         Bakery  0.13
# 2       Pharmacy  0.07
# 3          Plaza  0.07
# 4  Grocery Store  0.07
#
#
# ---- Budafok----
#            venue  freq
# 0       Bus Stop  0.33
# 1     Playground  0.17
# 2  Grocery Store  0.17
# 3           Park  0.17
# 4    Supermarket  0.17
#
#
# ---- Budakeszierdő----
#               venue  freq
# 0     Historic Site   1.0
# 1       Yoga Studio   0.0
# 2      Perfume Shop   0.0
# 3  Pedestrian Plaza   0.0
# 4       Pastry Shop   0.0
#
#
# ---- Budaliget----
#                venue  freq
# 0           Bus Stop  0.50
# 1                Gym  0.25
# 2         Food Truck  0.25
# 3        Yoga Studio  0.00
# 4  Outdoor Sculpture  0.00
#
#
# ---- Békásmegyer----
#                            venue  freq
# 0                     Playground  0.12
# 1                    Supermarket  0.06
# 2              Food & Drink Shop  0.06
# 3                           Park  0.06
# 4  Paper / Office Supplies Store  0.06
#
#
# ---- Cinkota----
#                    venue  freq
# 0               Bus Stop  0.67
# 1           Dessert Shop  0.17
# 2     Light Rail Station  0.17
# 3            Yoga Studio  0.00
# 4  Outdoors & Recreation  0.00
#
#
# ---- City Park----
#          venue  freq
# 0  Beer Garden  0.09
# 1         Park  0.09
# 2   Restaurant  0.09
# 3   Playground  0.09
# 4          Spa  0.06
#
#
# ---- Csatárka----
#            venue  freq
# 0   Squash Court  0.08
# 1  Bowling Alley  0.08
# 2  Grocery Store  0.08
# 3     Shoe Store  0.08
# 4            Bar  0.08
#
#
# ---- Csillaghegy----
#                            venue  freq
# 0                     Restaurant  0.09
# 1  Vegetarian / Vegan Restaurant  0.09
# 2           Hungarian Restaurant  0.09
# 3                Motorcycle Shop  0.09
# 4                    Pastry Shop  0.09
#
#
# ---- Csillebérc----
#          venue  freq
# 0        Field  0.25
# 1  Bus Station  0.25
# 2         Park  0.25
# 3      Dog Run  0.25
# 4  Yoga Studio  0.00
#
#
# ---- Csúcshegy----
#                venue  freq
# 0           Vineyard   1.0
# 1        Yoga Studio   0.0
# 2  Outdoor Sculpture   0.0
# 3   Pedestrian Plaza   0.0
# 4        Pastry Shop   0.0
#
#
# ---- Dobogó----
#                      venue  freq
# 0                 Bus Stop   0.4
# 1  Fruit & Vegetable Store   0.2
# 2          Nature Preserve   0.2
# 3                Racetrack   0.2
# 4        Outdoor Sculpture   0.0
#
#
# ---- Erzsébetliget----
#            venue  freq
# 0       Bus Stop  0.23
# 1           Café  0.15
# 2  Shopping Mall  0.08
# 3   Burger Joint  0.08
# 4        Dog Run  0.08
#
#
# ---- Erzsébettelek----
#            venue  freq
# 0  Grocery Store  0.09
# 1       Bus Stop  0.09
# 2    Pizza Place  0.06
# 3         Bakery  0.06
# 4    Flower Shop  0.06
#
#
# ---- Farkasrét----
#           venue  freq
# 0      Bus Stop   0.2
# 1    Playground   0.1
# 2  Tram Station   0.1
# 3  Dessert Shop   0.1
# 4           Pub   0.1
#
#
# ---- Farkasvölgy----
#           venue  freq
# 0           Gym  0.12
# 1      Bus Stop  0.12
# 2          Park  0.12
# 3  Gourmet Shop  0.12
# 4         Plaza  0.12
#
#
# ---- Felhévíz----
#             venue  freq
# 0    Dessert Shop  0.05
# 1          Bistro  0.05
# 2  Breakfast Spot  0.05
# 3   Grocery Store  0.05
# 4            Park  0.05
#
#
# ---- Filatorigát----
#                   venue  freq
# 0                 Diner  0.12
# 1     Recreation Center  0.06
# 2           Men's Store  0.06
# 3  Fast Food Restaurant  0.06
# 4    Photography Studio  0.06
#
#
# ---- Gazdagrét----
#            venue  freq
# 0     Playground  0.17
# 1   Burger Joint  0.06
# 2          Plaza  0.06
# 3           Café  0.06
# 4  Grocery Store  0.06
#
#
# ---- Gellérthegy----
#          venue  freq
# 0     Bus Stop  0.15
# 1   Playground  0.15
# 2     Mountain  0.08
# 3       Garden  0.08
# 4  Beer Garden  0.08
#
#
# ---- Gercse----
#                          venue  freq
# 0               Scenic Lookout   0.5
# 1  Eastern European Restaurant   0.5
# 2                  Yoga Studio   0.0
# 3        Performing Arts Venue   0.0
# 4                  Pastry Shop   0.0
#
#
# ---- Gubacsidűlő----
#           venue  freq
# 0  Dance Studio  0.25
# 1     Rock Club  0.25
# 2   Music Venue  0.25
# 3  Intersection  0.25
# 4    Waterfront  0.00
#
#
# ---- Gyárdűlő----
#                     venue  freq
# 0  Furniture / Home Store  0.14
# 1            Soccer Field  0.14
# 2            Tram Station  0.14
# 3       Electronics Store  0.07
# 4                 Stadium  0.07
#
#
# ---- Göncz Árpád városközpont----
#                  venue  freq
# 0          Coffee Shop  0.12
# 1   Chinese Restaurant  0.09
# 2  Fried Chicken Joint  0.06
# 3                  Pub  0.06
# 4          Pizza Place  0.06
#
#
# ---- Herminamező----
#                   venue  freq
# 0                Buffet  0.12
# 1  Arts & Entertainment  0.12
# 2          Dessert Shop  0.12
# 3    Chinese Restaurant  0.12
# 4  Hungarian Restaurant  0.12
#
#
# ---- Hosszúrét----
#            venue  freq
# 0     Playground  0.23
# 1       Bus Stop  0.15
# 2    Yoga Studio  0.08
# 3          Plaza  0.08
# 4  Grocery Store  0.08
#
#
# ---- Hármashatár-hegy----
#             venue  freq
# 0      Restaurant  0.25
# 1        Mountain  0.25
# 2  Scenic Lookout  0.25
# 3       Nightclub  0.12
# 4     Coffee Shop  0.12
#
#
# ---- Hársakalja----
#                   venue  freq
# 0             Wine Shop  0.25
# 1              Bus Stop  0.25
# 2  Hungarian Restaurant  0.25
# 3           Pizza Place  0.25
# 4     Outdoor Sculpture  0.00
#
#
# ---- Hárshegy----
#                    venue  freq
# 0              Rest Area  0.33
# 1          Train Station  0.33
# 2         Scenic Lookout  0.33
# 3  Performing Arts Venue  0.00
# 4            Pastry Shop  0.00
#
#
# ---- Hűvösvölgy----
#            venue  freq
# 0  Grocery Store  0.13
# 1    Pizza Place  0.10
# 2    Flower Shop  0.03
# 3            Gym  0.03
# 4       Bus Stop  0.03
#
#
# ---- Ilonatelep----
#                 venue  freq
# 0            Bus Stop  0.50
# 1              Garden  0.25
# 2  Light Rail Station  0.25
# 3         Yoga Studio  0.00
# 4   Outdoor Sculpture  0.00
#
#
# ---- Istenhegy----
#               venue  freq
# 0     Grocery Store  0.17
# 1          Bus Stop  0.17
# 2    Ice Cream Shop  0.17
# 3  Sculpture Garden  0.17
# 4       Coffee Shop  0.17
#
#
# ---- Istvánmező----
#                          venue  freq
# 0                     Bus Stop  0.06
# 1  Eastern European Restaurant  0.06
# 2                          Bar  0.06
# 3                Grocery Store  0.06
# 4           Chinese Restaurant  0.06
#
#
# ---- Istvántelek.----
#            venue  freq
# 0       Bus Stop  0.25
# 1  Train Station  0.25
# 2      Cafeteria  0.25
# 3    Snack Place  0.25
# 4    Yoga Studio  0.00
#
#
# ---- Jánoshegy----
#                venue  freq
# 0     Scenic Lookout  0.50
# 1               Café  0.25
# 2           Mountain  0.25
# 3  Outdoor Sculpture  0.00
# 4        Pastry Shop  0.00
#
#
# ---- József Attila-lakótelep----
#             venue  freq
# 0          Bakery  0.25
# 1   Grocery Store  0.25
# 2        Bus Stop  0.12
# 3  Cosmetics Shop  0.12
# 4            Park  0.12
#
#
# ---- Kaszásdűlő----
#                    venue  freq
# 0      Electronics Store  0.50
# 1   Fast Food Restaurant  0.25
# 2          Grocery Store  0.25
# 3  Performing Arts Venue  0.00
# 4       Pedestrian Plaza  0.00
#
#
# ---- Kelenföld----
#           venue  freq
# 0      Bus Stop  0.11
# 1        Bakery  0.11
# 2           Pub  0.11
# 3    Playground  0.11
# 4  Dessert Shop  0.05
#
#
# ---- Kelenvölgy----
#             venue  freq
# 0        Bus Stop  0.27
# 1      Playground  0.09
# 2             Pub  0.09
# 3  Ice Cream Shop  0.09
# 4         Dog Run  0.09
#
#
# ---- Kerepesdűlő----
#                venue  freq
# 0     Clothing Store  0.18
# 1        Coffee Shop  0.10
# 2  Electronics Store  0.05
# 3           Boutique  0.05
# 4        Pizza Place  0.05
#
#
# ---- Keresztúridűlő----
#               venue  freq
# 0           Exhibit   1.0
# 1       Yoga Studio   0.0
# 2      Perfume Shop   0.0
# 3  Pedestrian Plaza   0.0
# 4       Pastry Shop   0.0
#
#
# ---- Kissvábhegy----
#                venue  freq
# 0             Bakery  0.12
# 1  Korean Restaurant  0.12
# 2               Park  0.12
# 3     Scenic Lookout  0.12
# 4     Farmers Market  0.12
#
#
# ---- Kisszentmihály----
#                      venue  freq
# 0  Fruit & Vegetable Store   0.4
# 1                 Bus Stop   0.2
# 2              Snack Place   0.2
# 3              Auto Garage   0.2
# 4    Outdoors & Recreation   0.0
#
#
# ---- Kiszugló----
#                   venue  freq
# 0            Restaurant  0.14
# 1    Chinese Restaurant  0.09
# 2          Dessert Shop  0.09
# 3                   Gym  0.09
# 4  Gym / Fitness Center  0.09
#
#
# ---- Kossuthfalva----
#                 venue  freq
# 0            Bus Stop  0.38
# 1  Athletics & Sports  0.12
# 2              Bakery  0.12
# 3            Pharmacy  0.12
# 4     Bed & Breakfast  0.12
#
#
# ---- Krisztinaváros----
#                   venue  freq
# 0                  Café  0.15
# 1                  Park  0.06
# 2            Playground  0.06
# 3  Gym / Fitness Center  0.06
# 4           Coffee Shop  0.06
#
#
# ---- Kurucles----
#                     venue  freq
# 0  Furniture / Home Store   0.2
# 1                Bus Stop   0.2
# 2                     Gym   0.2
# 3       Food & Drink Shop   0.2
# 4                   Hotel   0.2
#
#
# ---- Káposztásmegyer----
#                venue  freq
# 0  Electronics Store  0.67
# 1         Restaurant  0.17
# 2     Clothing Store  0.17
# 3        Yoga Studio  0.00
# 4    Paintball Field  0.00
#
#
# ---- Kútvölgy----
#            venue  freq
# 0       Bus Stop  0.44
# 1  Grocery Store  0.12
# 2         Forest  0.06
# 3     Restaurant  0.06
# 4     Steakhouse  0.06
#
#
# ---- Kőbánya-Kertváros----
#                          venue  freq
# 0                     Bus Stop  0.33
# 1             Department Store  0.17
# 2                Auto Workshop  0.17
# 3  Eastern European Restaurant  0.17
# 4                   Hobby Shop  0.17
#
#
# ---- Kővár----
#                venue  freq
# 0     Scenic Lookout  0.50
# 1            Airport  0.25
# 2           Mountain  0.25
# 3  Outdoor Sculpture  0.00
# 4        Pastry Shop  0.00
#
#
# ---- Lipótmező----
#            venue  freq
# 0      Multiplex  0.11
# 1    Pizza Place  0.11
# 2  Movie Theater  0.11
# 3           Café  0.11
# 4  Grocery Store  0.11
#
#
# ---- Lipótváros----
#                   venue  freq
# 0    Italian Restaurant  0.10
# 1           Coffee Shop  0.07
# 2                 Hotel  0.06
# 3                 Plaza  0.04
# 4  Hungarian Restaurant  0.04
#
#
# ---- Lágymányos----
#                    venue  freq
# 0                    Pub  0.10
# 1                    Bar  0.07
# 2      Electronics Store  0.07
# 3  Vietnamese Restaurant  0.05
# 4   Gym / Fitness Center  0.05
#
#
# ---- Madárdomb----
#                   venue  freq
# 0              Bus Stop  0.46
# 1  Gym / Fitness Center  0.08
# 2          Dessert Shop  0.08
# 3                   Pub  0.08
# 4              Pharmacy  0.08
#
#
# ---- Madárhegy----
#                venue  freq
# 0             Bakery   0.5
# 1        IT Services   0.5
# 2  Outdoor Sculpture   0.0
# 3   Pedestrian Plaza   0.0
# 4        Pastry Shop   0.0
#
#
# ---- Magasút----
#             venue  freq
# 0     Bus Station  0.12
# 1          Forest  0.12
# 2             Gym  0.12
# 3    Gourmet Shop  0.12
# 4  Scenic Lookout  0.12
#
#
# ---- Megyer----
#                venue  freq
# 0                Gym   0.5
# 1          Gastropub   0.5
# 2        Yoga Studio   0.0
# 3  Outdoor Sculpture   0.0
# 4        Pastry Shop   0.0
#
#
# ---- Mocsárosdűlő----
#                venue  freq
# 0         Playground  0.25
# 1          Racetrack  0.25
# 2              Field  0.25
# 3           Heliport  0.25
# 4  Outdoor Sculpture  0.00
#
#
# ---- Máriaremete----
#                   venue  freq
# 0              Bus Stop   0.3
# 1        Farmers Market   0.1
# 2    Italian Restaurant   0.1
# 3        Ice Cream Shop   0.1
# 4  Hungarian Restaurant   0.1
#
#
# ---- Mártonhegy----
#             venue  freq
# 0        Bus Stop  0.24
# 1      Playground  0.18
# 2           Plaza  0.06
# 3    Tennis Court  0.06
# 4  Farmers Market  0.06
#
#
# ---- Mátyáshegy----
#                 venue  freq
# 0                Cave   0.2
# 1       Deli / Bodega   0.1
# 2  Italian Restaurant   0.1
# 3          Sports Bar   0.1
# 4            Bus Stop   0.1
#
#
# ---- Nagyiccetelep----
#                 venue  freq
# 0            Bus Stop  0.43
# 1  Athletics & Sports  0.14
# 2                Café  0.14
# 3   Convenience Store  0.14
# 4   Electronics Store  0.14
#
#
# ---- Nagytétény----
#            venue  freq
# 0  Deli / Bodega  0.25
# 1       Platform  0.25
# 2         Garden  0.25
# 3  Train Station  0.25
# 4    Pastry Shop  0.00
#
#
# ---- Nagyzugló----
#                            venue  freq
# 0                       Bus Stop  0.12
# 1              Electronics Store  0.12
# 2                     Playground  0.06
# 3                       Boutique  0.06
# 4  Paper / Office Supplies Store  0.06
#
#
# ---- Nyék----
#                 venue  freq
# 0        Tennis Court  0.29
# 1  Athletics & Sports  0.14
# 2                Park  0.14
# 3            Bus Stop  0.14
# 4        Soccer Field  0.14
#
#
# ---- Németvölgy----
#                   venue  freq
# 0            Playground  0.06
# 1             Wine Shop  0.04
# 2              Boutique  0.04
# 3    Italian Restaurant  0.04
# 4  Gym / Fitness Center  0.04
#
#
# ---- Népsziget----
#         venue  freq
# 0   Beach Bar  0.17
# 1         Bar  0.08
# 2  Restaurant  0.08
# 3   Nightclub  0.08
# 4     Dog Run  0.08
#
#
# ---- Orbánhegy----
#                venue  freq
# 0           Bus Stop  0.21
# 1     Ice Cream Shop  0.14
# 2  Korean Restaurant  0.07
# 3      Grocery Store  0.07
# 4             Bakery  0.07
#
#
# ---- Országút----
#             venue  freq
# 0          Bakery  0.07
# 1     Coffee Shop  0.04
# 2  Breakfast Spot  0.04
# 3     Pizza Place  0.04
# 4    Dessert Shop  0.04
#
#
# ---- Pacsirtatelep----
#                venue  freq
# 0       Tram Station  0.62
# 1             Market  0.12
# 2         Steakhouse  0.12
# 3               Park  0.12
# 4  Outdoor Sculpture  0.00
#
#
# ---- Pasarét----
#                venue  freq
# 0           Bus Stop  0.15
# 1       Dessert Shop  0.07
# 2  Electronics Store  0.07
# 3                Bar  0.07
# 4       Tram Station  0.04
#
#
# ---- Pesterzsébet----
#                venue  freq
# 0           Bus Stop  0.50
# 1  Food & Drink Shop  0.17
# 2               Park  0.17
# 3      Grocery Store  0.17
# 4  Outdoor Sculpture  0.00
#
#
# ---- Pesthidegkút-Ófalu----
#                 venue  freq
# 0    Pedestrian Plaza   0.2
# 1                Park   0.2
# 2  Photography Studio   0.2
# 3               Hotel   0.2
# 4                Lake   0.2
#
#
# ---- Pestszentimre----
#            venue  freq
# 0  Grocery Store  0.20
# 1     Restaurant  0.13
# 2     Playground  0.07
# 3       Bus Stop  0.07
# 4            Bar  0.07
#
#
# ---- Pestújhely----
#         venue  freq
# 0  Restaurant  0.17
# 1    Bus Stop  0.17
# 2         Gym  0.17
# 3      Bakery  0.08
# 4    Pharmacy  0.08
#
#
# ---- Petőfikert----
#                   venue  freq
# 0            Playground   0.2
# 1     Food & Drink Shop   0.2
# 2           Beer Garden   0.2
# 3  Gym / Fitness Center   0.2
# 4              Bus Stop   0.2
#
#
# ---- Pálvölgy----
#           venue  freq
# 0          Cave  0.33
# 1  Soccer Field  0.17
# 2   Bus Station  0.17
# 3    Sports Bar  0.17
# 4         Hotel  0.17
#
#
# ---- Péterhegy----
#                      venue  freq
# 0                 Bus Stop  0.38
# 1  Fruit & Vegetable Store  0.12
# 2              Supermarket  0.12
# 3                    Hotel  0.12
# 4             Tennis Court  0.12
#
#
# ---- Pösingermajor----
#                   venue  freq
# 0           Golf Course   0.2
# 1                Forest   0.2
# 2     Convenience Store   0.2
# 3  Other Great Outdoors   0.2
# 4          Tennis Court   0.2
#
#
# ---- Remetehegy----
#                 venue  freq
# 0                Road  0.25
# 1      Breakfast Spot  0.25
# 2            Bus Stop  0.25
# 3  Athletics & Sports  0.25
# 4         Yoga Studio  0.00
#
#
# ---- Remetekertváros----
#                 venue  freq
# 0        Dessert Shop   0.4
# 1  Salon / Barbershop   0.2
# 2       Grocery Store   0.2
# 3            Pharmacy   0.2
# 4   Outdoor Sculpture   0.0
#
#
# ---- Rákoscsaba-Újtelep----
#                 venue  freq
# 0  Athletics & Sports  0.17
# 1        Soccer Field  0.17
# 2               Diner  0.17
# 3             Dog Run  0.17
# 4               Trail  0.17
#
#
# ---- Rákoshegy----
#                   venue  freq
# 0          Dessert Shop  0.17
# 1         Grocery Store  0.17
# 2              Bus Stop  0.17
# 3                  Park  0.17
# 4  Fast Food Restaurant  0.17
#
#
# ---- Rákoskert----
#                venue  freq
# 0   Video Game Store  0.25
# 1               Café  0.25
# 2         Food Truck  0.25
# 3                Bar  0.25
# 4  Outdoor Sculpture  0.00
#
#
# ---- Rákosliget----
#                   venue  freq
# 0              Bus Stop  0.38
# 1           Music Venue  0.08
# 2               Theater  0.08
# 3                Bakery  0.08
# 4  Hungarian Restaurant  0.08
#
#
# ---- Rákosszentmihály----
#                 venue  freq
# 0            Bus Stop  0.18
# 1  Athletics & Sports  0.18
# 2                 Gym  0.09
# 3              Bakery  0.09
# 4       Grocery Store  0.09
#
#
# ---- Régiakadémiatelep----
#                    venue  freq
# 0                  Diner   0.4
# 1             Restaurant   0.2
# 2               Bus Stop   0.2
# 3            Coffee Shop   0.2
# 4  Outdoors & Recreation   0.0
#
#
# ---- Rézmál----
#            venue  freq
# 0  Grocery Store  0.14
# 1       Bus Stop  0.14
# 2  Deli / Bodega  0.14
# 3          Plaza  0.10
# 4        Theater  0.05
#
#
# ---- Rómaifürdő----
#              venue  freq
# 0         Bus Stop  0.18
# 1      Yoga Studio  0.09
# 2           Bakery  0.09
# 3  Harbor / Marina  0.09
# 4              Gym  0.09
#
#
# ---- Rózsadomb----
#                   venue  freq
# 0              Bus Stop  0.20
# 1                  Park  0.13
# 2           Yoga Studio  0.13
# 3  Gym / Fitness Center  0.07
# 4    Italian Restaurant  0.07
#
#
# ---- Sasad----
#                venue  freq
# 0         Playground  0.12
# 1           Bus Stop  0.12
# 2               Park  0.12
# 3  Recreation Center  0.06
# 4         Food Truck  0.06
#
#
# ---- Sashalom----
#                      venue  freq
# 0                 Bus Stop  0.20
# 1            Grocery Store  0.15
# 2                Pet Store  0.10
# 3       Light Rail Station  0.05
# 4  Fruit & Vegetable Store  0.05
#
#
# ---- Sashegy----
#                   venue  freq
# 0            Playground  0.17
# 1              Bus Stop  0.17
# 2  Hungarian Restaurant  0.17
# 3                  Park  0.17
# 4    Light Rail Station  0.17
#
#
# ---- Solymárvölgy----
#                venue  freq
# 0       Burger Joint  0.25
# 1              River  0.25
# 2      Train Station  0.25
# 3        Beer Garden  0.25
# 4  Outdoor Sculpture  0.00
#
#
# ---- Spanyolrét----
#            venue  freq
# 0       Bus Stop   0.4
# 1  Grocery Store   0.2
# 2    IT Services   0.2
# 3     Smoke Shop   0.2
# 4    Yoga Studio   0.0
#
#
# ---- Svábhegy----
#                    venue  freq
# 0               Bus Stop  0.50
# 1          Historic Site  0.25
# 2                  Hotel  0.25
# 3            Yoga Studio  0.00
# 4  Outdoors & Recreation  0.00
#
#
# ---- Szabadságtelep----
#                   venue  freq
# 0               Stadium  0.25
# 1               Theater  0.25
# 2         Train Station  0.25
# 3           Supermarket  0.25
# 4  Other Great Outdoors  0.00
#
#
# ---- Szemlőhegy----
#                 venue  freq
# 0            Bus Stop  0.25
# 1          Restaurant  0.10
# 2       Grocery Store  0.10
# 3               Track  0.10
# 4  Athletics & Sports  0.05
#
#
# ---- Széchenyihegy----
#                venue  freq
# 0         Playground   0.4
# 1     Scenic Lookout   0.4
# 2            Dog Run   0.2
# 3  Other Repair Shop   0.0
# 4        Pastry Shop   0.0
#
#
# ---- Székesdűlő----
#                   venue  freq
# 0              Bus Stop   0.4
# 1            Restaurant   0.2
# 2         Grocery Store   0.2
# 3  Hungarian Restaurant   0.2
# 4           Yoga Studio   0.0
#
#
# ---- Széphalom----
#            venue  freq
# 0       Bus Stop  0.23
# 1  Shopping Mall  0.08
# 2       Pharmacy  0.08
# 3           Café  0.08
# 4    Pastry Shop  0.08
#
#
# ---- Szépilona----
#           venue  freq
# 0      Bus Stop  0.17
# 1          Café  0.08
# 2       Theater  0.08
# 3      Pharmacy  0.08
# 4  Tram Station  0.04
#
#
# ---- Szépvölgy----
#                    venue  freq
# 0                  Track  0.25
# 1             Restaurant  0.25
# 2                  Trail  0.25
# 3  Outdoors & Recreation  0.25
# 4            Yoga Studio  0.00
#
#
# ---- Tabán----
#            venue  freq
# 0           Park  0.11
# 1  Historic Site  0.06
# 2   Dessert Shop  0.04
# 3       Wine Bar  0.04
# 4         Bistro  0.04
#
#
# ---- Testvérhegy----
#                venue  freq
# 0               Café  0.25
# 1           Bus Stop  0.25
# 2           Mountain  0.25
# 3  Food & Drink Shop  0.25
# 4  Outdoor Sculpture  0.00
#
#
# ---- Tisztviselőtelep----
#                 venue  freq
# 0               Hotel  0.19
# 1            Bus Stop  0.15
# 2  Athletics & Sports  0.12
# 3    Basketball Court  0.04
# 4           Nightclub  0.04
#
#
# ---- Táborhegy----
#                   venue  freq
# 0               Stadium   0.5
# 1  Hungarian Restaurant   0.5
# 2     Other Repair Shop   0.0
# 3           Pastry Shop   0.0
# 4                  Park   0.0
#
#
# ---- Törökkő----
#                          venue  freq
# 0                     Bus Stop  0.20
# 1             Department Store  0.07
# 2                  Auto Garage  0.07
# 3  Eastern European Restaurant  0.07
# 4         Fast Food Restaurant  0.07
#
#
# ---- Törökvész----
#                   venue  freq
# 0            Playground  0.33
# 1              Bus Stop  0.17
# 2           Supermarket  0.17
# 3  Hungarian Restaurant  0.17
# 4               Stables  0.17
#
#
# ---- Törökőr----
#              venue  freq
# 0       Theme Park  0.11
# 1  Bed & Breakfast  0.11
# 2              Bar  0.11
# 3              Gym  0.11
# 4   Cosmetics Shop  0.11
#
#
# ---- Virányos.----
#            venue  freq
# 0     Playground  0.33
# 1     Restaurant  0.17
# 2   Burger Joint  0.17
# 3  Grocery Store  0.17
# 4     Food Truck  0.17
#
#
# ---- Vizafogó----
#                      venue  freq
# 0            Grocery Store  0.09
# 1     Gym / Fitness Center  0.07
# 2                 Bus Stop  0.07
# 3              Coffee Shop  0.07
# 4  Health & Beauty Service  0.04
#
#
# ---- Vérhalom----
#                        venue  freq
# 0                    Dog Run  0.12
# 1                  Wine Shop  0.06
# 2                     Bakery  0.06
# 3  Middle Eastern Restaurant  0.06
# 4                       Park  0.06
#
#
# ---- Wekerletelep----
#        venue  freq
# 0   Bus Stop  0.16
# 1       Park  0.16
# 2       Café  0.08
# 3  Wine Shop  0.04
# 4   Pharmacy  0.04
#
#
# ---- Zöldmál.----
#                  venue  freq
# 0             Bus Stop   0.5
# 1            Wine Shop   0.1
# 2  Japanese Restaurant   0.1
# 3          Snack Place   0.1
# 4          Pizza Place   0.1
#
#
# ---- Árpádföld----
#                venue  freq
# 0           Bus Stop  0.29
# 1         Restaurant  0.14
# 2      Grocery Store  0.07
# 3  Food & Drink Shop  0.07
# 4               Park  0.07
#
#
# ---- Óbudai-sziget----
#                venue  freq
# 0         Playground  0.11
# 1    Harbor / Marina  0.11
# 2  Recreation Center  0.06
# 3                Gym  0.06
# 4             Bakery  0.06
#
#
# ---- Örsöd----
#                venue  freq
# 0     Farmers Market  0.17
# 1           Bus Stop  0.17
# 2           Ski Area  0.17
# 3        Flea Market  0.17
# 4  Convenience Store  0.17
#
#
# ---- Újpalota----
#                     venue  freq
# 0                  Bakery  0.14
# 1          Cosmetics Shop  0.14
# 2  Furniture / Home Store  0.14
# 3           Grocery Store  0.14
# 4       Food & Drink Shop  0.14
#
#
# ---- Őrmező----
#                venue  freq
# 0                Pub  0.33
# 1              Diner  0.33
# 2   Business Service  0.33
# 3        Yoga Studio  0.00
# 4  Outdoor Sculpture  0.00
#
#
# ----Adyliget----
#          venue  freq
# 0   Playground   0.2
# 1         Park   0.2
# 2     Bus Stop   0.2
# 3     Pharmacy   0.2
# 4  Pizza Place   0.2
#
#
# ----Albertfalva----
#           venue  freq
# 0           Pub  0.14
# 1   Supermarket  0.14
# 2  Intersection  0.07
# 3  Tram Station  0.07
# 4       Dog Run  0.07
#
#
# ----Alsórákos----
#            venue  freq
# 0       Bus Stop  0.21
# 1   Dessert Shop  0.14
# 2  Grocery Store  0.14
# 3          Plaza  0.14
# 4     Playground  0.14
#
#
# ----Belváros----
#           venue  freq
# 0   Coffee Shop  0.14
# 1         Plaza  0.05
# 2  Burger Joint  0.04
# 3    Restaurant  0.04
# 4         Hotel  0.04
#
#
# ----Buda Castle----
#                   venue  freq
# 0                  Park  0.10
# 1  Hungarian Restaurant  0.08
# 2        Scenic Lookout  0.08
# 3                   Pub  0.08
# 4                 Plaza  0.08
#
#
# ----Budakeszierdő----
#               venue  freq
# 0     Historic Site   1.0
# 1       Yoga Studio   0.0
# 2      Perfume Shop   0.0
# 3  Pedestrian Plaza   0.0
# 4       Pastry Shop   0.0
#
#
# ----Budatétény----
#              venue  freq
# 0              Pub   0.2
# 1         Bus Stop   0.2
# 2  Paintball Field   0.2
# 3     Soccer Field   0.2
# 4      Flower Shop   0.2
#
#
# ----Bulls Park Crossfit----
#                   venue  freq
# 0                 Diner  0.07
# 1           Art Gallery  0.07
# 2  Gym / Fitness Center  0.07
# 3                   Gym  0.07
# 4           Supermarket  0.04
#
#
# ----Crossfit BBros----
#                     venue  freq
# 0              Playground  0.14
# 1   Performing Arts Venue  0.07
# 2             Music Venue  0.07
# 3  Furniture / Home Store  0.03
# 4    Gym / Fitness Center  0.03
#
#
# ----Crossfit BBros 2----
#                      venue  freq
# 0                     Park  0.11
# 1             Burger Joint  0.06
# 2             Tram Station  0.06
# 3               Campground  0.06
# 4  Fruit & Vegetable Store  0.06
#
#
# ----Crossfit Bloodfit----
#                 venue  freq
# 0               Diner  0.09
# 1  Chinese Restaurant  0.05
# 2  Turkish Restaurant  0.05
# 3         Coffee Shop  0.05
# 4       Grocery Store  0.05
#
#
# ----Crossfit Budapest----
#                   venue  freq
# 0              Bus Stop  0.12
# 1         Deli / Bodega  0.06
# 2                 Hotel  0.06
# 3  Gym / Fitness Center  0.06
# 4                  Park  0.06
#
#
# ----Crossfit Corvinus----
#                    venue  freq
# 0               Bus Stop  0.31
# 1          Deli / Bodega  0.08
# 2  Vietnamese Restaurant  0.08
# 3                   Park  0.08
# 4   Gym / Fitness Center  0.08
#
#
# ----Crossfit Everybody----
#                   venue  freq
# 0                   Bar  0.25
# 1              Bus Stop  0.25
# 2              Aquarium  0.25
# 3  Hungarian Restaurant  0.25
# 4       Paintball Field  0.00
#
#
# ----Crossfit Glasshouse----
#                          venue  freq
# 0         Fast Food Restaurant  0.09
# 1         Gym / Fitness Center  0.06
# 2                  Art Gallery  0.06
# 3                        Diner  0.06
# 4  Eastern European Restaurant  0.03
#
#
# ----Crossfit Grund----
#                            venue  freq
# 0                    Coffee Shop  0.09
# 1                 Ice Cream Shop  0.06
# 2                   Dessert Shop  0.05
# 3                         Bakery  0.05
# 4  Vegetarian / Vegan Restaurant  0.05
#
#
# ----Crossfit Mayfly----
#                  venue  freq
# 0        Grocery Store  0.13
# 1          Auto Garage  0.07
# 2         Concert Hall  0.07
# 3           Restaurant  0.07
# 4  Fried Chicken Joint  0.07
#
#
# ----Crossfit Tesseract----
#                   venue  freq
# 0              Bus Stop  0.11
# 1  Fast Food Restaurant  0.11
# 2    Athletics & Sports  0.11
# 3          Tram Station  0.06
# 4                  Café  0.06
#
#
# ----Crossfit Újbuda----
#                   venue  freq
# 0            Restaurant  0.09
# 1    Italian Restaurant  0.05
# 2   Fried Chicken Joint  0.05
# 3  Gym / Fitness Center  0.05
# 4                   Gym  0.05
#
#
# ----Csepel----
#                     venue  freq
# 0           Grocery Store  0.12
# 1             Beer Garden  0.08
# 2                  Bakery  0.08
# 3  Thrift / Vintage Store  0.04
# 4        Pedestrian Plaza  0.04
#
#
# ----Erzsébetváros----
#                          venue  freq
# 0                     Bus Stop  0.10
# 1         Fast Food Restaurant  0.07
# 2                        Diner  0.07
# 3                  Yoga Studio  0.03
# 4  Eastern European Restaurant  0.03
#
#
# ----Felsőrákos----
#                            venue  freq
# 0                        Stables   1.0
# 1              Other Repair Shop   0.0
# 2                    Pastry Shop   0.0
# 3                           Park   0.0
# 4  Paper / Office Supplies Store   0.0
#
#
# ----Ferencváros----
#                venue  freq
# 0      Train Station   0.4
# 1         Restaurant   0.2
# 2             Office   0.2
# 3  Electronics Store   0.2
# 4        Yoga Studio   0.0
#
#
# ----Gubacsipuszta----
#                    venue  freq
# 0          Grocery Store  0.50
# 1                   Park  0.25
# 2                   Farm  0.25
# 3            Yoga Studio  0.00
# 4  Outdoors & Recreation  0.00
#
#
# ----Józsefváros----
#            venue  freq
# 0       Bus Stop  0.15
# 1          Plaza  0.15
# 2  Grocery Store  0.08
# 3         Bakery  0.08
# 4     Smoke Shop  0.08
#
#
# ----Kispest----
#             venue  freq
# 0        Bus Stop  0.33
# 1  Ice Cream Shop  0.17
# 2       Nightclub  0.17
# 3   Grocery Store  0.17
# 4    Tram Station  0.17
#
#
# ----Mátyásföld----
#          venue  freq
# 0     Bus Stop  0.29
# 1  Yoga Studio  0.14
# 2   Water Park  0.14
# 3  Beer Garden  0.14
# 4         Café  0.14
#
#
# ----Pestszentlőrinc----
#                   venue  freq
# 0              Bus Stop  0.25
# 1         Deli / Bodega  0.08
# 2  Gym / Fitness Center  0.08
# 3              Pharmacy  0.08
# 4                  Park  0.08
#
#
# ----Petneházyrét----
#                venue  freq
# 0        Sports Club  0.25
# 1         Restaurant  0.25
# 2              Hotel  0.25
# 3       Tennis Court  0.25
# 4  Other Repair Shop  0.00
#
#
# ----Reebok Crossfit Duna----
#       venue  freq
# 0       Bar  0.17
# 1  Wine Bar  0.17
# 2    Island  0.17
# 3     Diner  0.17
# 4   Gay Bar  0.17
#
#
# ----Rákoskeresztúr----
#           venue  freq
# 0   Flower Shop  0.08
# 1  Soccer Field  0.08
# 2        Garden  0.08
# 3      Bus Stop  0.08
# 4        Bakery  0.08
#
#
# ----Rákospalota----
#                venue  freq
# 0   Baseball Stadium  0.33
# 1        Supermarket  0.33
# 2               Lake  0.33
# 3  Outdoor Sculpture  0.00
# 4   Pedestrian Plaza  0.00
#
#
# ----Szabótelep----
#                    venue  freq
# 0               Bus Stop   0.8
# 1        Bed & Breakfast   0.2
# 2            Yoga Studio   0.0
# 3  Outdoors & Recreation   0.0
# 4       Pedestrian Plaza   0.0
#
#
# ----Szent György telep----
#         venue  freq
# 0  Playground  0.25
# 1  Food Court  0.25
# 2    Bus Stop  0.25
# 3        Pool  0.25
# 4        Park  0.00
#
#
# ----Terézváros----
#                    venue  freq
# 0            Coffee Shop  0.08
# 1                 Bakery  0.06
# 2                    Pub  0.06
# 3         Ice Cream Shop  0.04
# 4  Vietnamese Restaurant  0.04
#
#
# ----Víziváros----
#                          venue  freq
# 0               Breakfast Spot  0.09
# 1                       Bakery  0.07
# 2  Eastern European Restaurant  0.05
# 3                  Coffee Shop  0.05
# 4                      Theater  0.05
#
#
# ----Óbuda----
#                   venue  freq
# 0  Hungarian Restaurant  0.09
# 1          Dessert Shop  0.06
# 2         Grocery Store  0.06
# 3          Burger Joint  0.06
# 4                 Diner  0.06
#
#
# ----Újlak----
#                venue  freq
# 0           Pharmacy   1.0
# 1        Yoga Studio   0.0
# 2  Outdoor Sculpture   0.0
# 3        Pastry Shop   0.0
# 4               Park   0.0
#
#
# ----Újlipótváros----
#            venue  freq
# 0  Boat or Ferry  0.08
# 1   Gourmet Shop  0.06
# 2   Dessert Shop  0.06
# 3    Coffee Shop  0.06
# 4         Bakery  0.06
#
#
# ----Újpest----
#          venue  freq
# 0     Bus Stop  0.27
# 1         Park  0.18
# 2  Yoga Studio  0.09
# 3        Hotel  0.09
# 4   Restaurant  0.09

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted_total_bp = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted_total_bp['Neighborhood'] = total_bp_grouped['Neighborhood']

for ind in np.arange(total_bp_grouped.shape[0]):
    neighborhoods_venues_sorted_total_bp.iloc[ind, 1:] = return_most_common_venues(total_bp_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted_total_bp.head()
# Out:
#        Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0   Akadémiaújtelep                Bakery                  Park
# 1        Angyalföld    Light Rail Station                Bistro
# 2          Aquincum         Historic Site                Bakery
# 3           Budafok              Bus Stop         Grocery Store
# 4     Budakeszierdő         Historic Site             Wine Shop
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0  Fast Food Restaurant              Pharmacy    Falafel Restaurant
# 1          Tram Station                   Gym     Fish & Chips Shop
# 2           Karaoke Bar      Greek Restaurant    Light Rail Station
# 3            Playground           Supermarket                  Park
# 4           Fabric Shop                  Farm        Farmers Market
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0                  Farm        Farmers Market                 Field
# 1    Falafel Restaurant                  Farm        Farmers Market
# 2                   Bar         Grocery Store                   Gym
# 3           Fish Market                  Farm        Farmers Market
# 4  Fast Food Restaurant                 Field     Fish & Chips Shop
#
#   9th Most Common Venue 10th Most Common Venue
# 0     Fish & Chips Shop              Wine Shop
# 1  Fast Food Restaurant                  Field
# 2         Train Station               Pharmacy
# 3  Fast Food Restaurant                  Field
# 4           Fish Market            Flea Market

# %% [markdown]
# For the record, it can give a good insight if I check the population distribution among the 1st most common venue. As the result shows, the most common venues are the bus stops, grocery stores and playgrounds.

# %%
neighborhoods_venues_sorted_total_bp['1st Most Common Venue'].value_counts()
# Out:
# Bus Stop                       47
# Grocery Store                  11
# Playground                      7
# Bakery                          5
# Scenic Lookout                  5
# Park                            5
# Hungarian Restaurant            4
# Coffee Shop                     4
# Historic Site                   3
# Bar                             3
# Dog Run                         3
# Diner                           3
# Pub                             3
# Fast Food Restaurant            2
# Mountain                        2
# Athletics & Sports              2
# Electronics Store               2
# Café                            2
# Gym                             2
# Cave                            2
# Restaurant                      2
# Track                           1
# Beach Bar                       1
# Ice Cream Shop                  1
# Art Gallery                     1
# Wine Bar                        1
# Clothing Store                  1
# Burger Joint                    1
# Business Service                1
# Exhibit                         1
# Racetrack                       1
# Tram Station                    1
# Fruit & Vegetable Store         1
# Deli / Bodega                   1
# Wine Shop                       1
# Italian Restaurant              1
# Gym / Fitness Center            1
# Stables                         1
# Theater                         1
# Flower Shop                     1
# Pedestrian Plaza                1
# IT Services                     1
# Dance Studio                    1
# Train Station                   1
# Gastropub                       1
# Hotel                           1
# Vineyard                        1
# Forest                          1
# Eastern European Restaurant     1
# Tennis Court                    1
# Sports Club                     1
# Breakfast Spot                  1
# Boat or Ferry                   1
# Harbor / Marina                 1
# Buffet                          1
# Stadium                         1
# Dessert Shop                    1
# Snack Place                     1
# Gourmet Shop                    1
# Light Rail Station              1
# Soccer Field                    1
# Food Court                      1
# Pharmacy                        1
# Pizza Place                     1
# Baseball Stadium                1
# Name: 1st Most Common Venue, dtype: int64

# %% [markdown]
# Once the most common venues dataset is available for the Budapest neighborhoods and Crossfit Boxes, all the preparations has been made to start creating the clustering model.
